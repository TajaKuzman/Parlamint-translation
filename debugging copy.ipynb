# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=7
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=7

# %%
# Define the language code, used in the file names
lang_code = "CZ"

# Main path
main_path = "/home/tajak/Parlamint-translation"

# --------------------NO CHANGING OF THE CODE NEEDED FROM NOW ONWARDS------------------
import pandas as pd

translated_dataframe_path = "{}/results/{}/ParlaMint-{}-translated.csv".format(main_path, lang_code, lang_code)
translated_tokenized_dataframe_path = "{}/results/{}/ParlaMint-{}-translated-tokenized.csv".format(main_path,lang_code, lang_code)
final_dataframe = "{}/results/{}/ParlaMint-{}-final-dataframe.csv".format(main_path,lang_code, lang_code)

# %%
df.iloc[1236912].to_dict()
# Out:
# {'file_path': '/home/tajak/Parlamint-translation/Source-data/ParlaMint-CZ.conllu/ParlaMint-CZ.conllu/2015/ParlaMint-CZ_2015-01-23-ps2013-025-04-004-088.conllu',
#  'file': 'ParlaMint-CZ_2015-01-23-ps2013-025-04-004-088.conllu',
#  'sentence_id': 'ParlaMint-CZ_2015-01-23-ps2013-025-04-004-088.u8.p1.s5',
#  'text': 'To -',
#  'tokenized_text': 'To -',
#  'proper_nouns': '{}',
#  'length': 2,
#  'translation': "It's--",
#  'translation-tokenized': "It's--",
#  'space-after-information': "['Last']"}

# %%
aligns_list = open("eflomal/source-en_{}.rev".format(lang_code), "r").readlines()

aligns_list = aligns_list[:10]

# Create forward target alignments from the source alignment direction (by changing the direction in the rev file)
#aligns_list = open("source-en_{}.rev".format(lang_code), "r").readlines()
aligns_list = [i.replace("\n", "") for i in aligns_list]

# Continue with processing the list to create the final alignments format which I'll use to correct proper names
aligns_list = [i.split(" ") for i in aligns_list]

for i in aligns_list:
	# If alignment line is empty, keep the dictionary empty
	if len(i) == 1 and len(i[0]) == 0:
		aligns_list[aligns_list.index(i)] = []
	else:
		for pair in i:
			current_pair = pair.split("-")
			i[i.index(pair)] = {int(current_pair[0]): int(current_pair[1])}

len(aligns_list)
# Out:
# 10

# %%
final_aligns = []

# Create a dictionary out of the rev alignments
for i in aligns_list:
	current_line = {}

	try:
		for element in i:
			a = list(element.items())[0][0]
			b = list(element.items())[0][1]
			current_line[a] = b
	
		# Check whether the number of pairs in the list is the same as number of items
		if len(i) != len(list(current_line.items())):
			print("Not okay:")
			print(i)
			print(current_line)

		final_aligns.append(current_line)
	
	except:
		print("error")
		print(aligns_list.index(i))
		print(i)
		final_aligns.append("Error")
	
print("\nNumber of aligned sentences: {}\n\n".format(len(final_aligns)))

len(final_aligns)
# Out:
# Number of aligned sentences: 10
# 10

# %%
# Create a dictionary from the returned alignment files which will be added to each word in the final conllu

def alignment_file_to_target_dict(file):
	"""
	The output of the eflomal aligner is in the source to target direction. We want to get the alignments in the other direction
	and for each target word add to the conllu its aligned source word index (as it appears in conllu). In conllu, indices start
	with 1, not 0. So, we take the eflomal files, reverse the order and create dictionaries with target indexes as keys
	and source indexes as values. If there are more than one words aligned to the same target word, it looks like this: '1, 2'.
	We use the conllu indexes which means that we add 1 to each index in the alingment pairs. 

	Args:
		- file: the path to the .fwd and .rev file that is produced by the eflomal tool

	The result is a list of dictionaries, each dictionary corresponds to one sentence.
	"""
	# Create target alignments from the source alignment direction (by changing the direction in the file)
	aligns_list_target = open(file, "r").readlines()
	aligns_list_target = [i.replace("\n", "") for i in aligns_list_target]
	aligns_list_target = [i.split(" ") for i in aligns_list_target]

	aligns_list_target_dict_list = []

	# Loop through the alignments for sentences
	for i in aligns_list_target:
		# Create a dictionary for each sentence
		current_sentence_align = {}
		# If alignment line is empty, keep the dictionary empty
		if len(i) == 1 and len(i[0]) == 0:
			current_sentence_align = {}
		else:
			# For each alignment pair in the sentence:
			for pair in i:
				# Split the pair: result is a list of lists with source index as the first element
				# and target index as the second element: [[0,0], [1,2], [1,3]]
				current_pair = pair.split("-")

				# Get the indices for target and source and add 1 to them (to get the conllu indices)
				current_t_index = int(current_pair[1]) + 1
				current_s_index = int(current_pair[0]) + 1

				# Check whether the target index is already aligned to anything (a case of 1-to-many alignment),
				# if not, save it as a key and save the source index as value.
				if current_sentence_align.get(current_t_index, None) == None:
					current_sentence_align[current_t_index] = str(current_s_index)
				# If the index was already aligned to a previous source word, add the additional source word alignment as a string
				# (result: {0: "1, 2"))
				else:
					current_sentence_align[current_t_index] += str(", ")
					current_sentence_align[current_t_index] += str(current_s_index)

		aligns_list_target_dict_list.append(current_sentence_align)

	return aligns_list_target_dict_list

def correct_proper_nouns(translated_tokenized_dataframe_path, final_dataframe, lang_code):
	"""
	This function takes the translated text and the source text, aligns words with eflomal and corrects proper nouns.
	It takes the dataframe that was created in the function extract_text() and to which the translation was added
	in the function translate().

	To use eflomal, you need to install it first:
	# !git clone https://github.com/robertostling/eflomal
	# %cd eflomal
	# !make
	# !sudo make install
	# !python3 setup.py install

	In case you don't have sudo permission, you can skip !sudo make install. I did, and I also used a virtual environment (venv), and managed to install eflomal.

	"""
	import pandas as pd
	import re
	import ast
	from IPython.display import display
	import time
	import subprocess
	import os

	# Open the file, created in the previous step
	df = pd.read_csv("{}".format(translated_tokenized_dataframe_path), sep="\t", index_col=0)

	# Move into the eflomal folder
	os.chdir("/home/tajak/Parlamint-translation/eflomal")

	# Then we need to create files for all texts and all translations
	source_sentences = open("source_sentences_{}.txt".format(lang_code), "w")
	English_sentences = open("English_sentences_{}.txt".format(lang_code), "w")

	for i in df["tokenized_text"].to_list():
		source_sentences.write(i)
		source_sentences.write("\n")

	for i in df["translation-tokenized"].to_list():
		English_sentences.write(i)
		English_sentences.write("\n")

	source_sentences.close()
	English_sentences.close()

	print("\n\n")
	print("Alignment started.")
	start_time = time.time()

	# Align sentences with eflomal and get out a file with alignments
	#!python3 align.py -s source_sentences.txt -t English_sentences.txt --model 3 -r source-en.rev -f source-en.fwd
	subprocess.call(["/home/tajak/Parlamint-translation/align.sh", lang_code])

	# Create a list of dictionaries of alignments from the returned files which will be added to the final conllu for each word
	forward_alignment_dict_list = alignment_file_to_target_dict("source-en_{}.fwd".format(lang_code))
	backward_alignment_dict_list = alignment_file_to_target_dict("source-en_{}.rev".format(lang_code))

	# Add to the df
	df["fwd_align_dict"] = forward_alignment_dict_list
	df["bwd_align_dict"] = backward_alignment_dict_list

	# Create forward target alignments from the source alignment direction (by changing the direction in the rev file)
	aligns_list = open("source-en_{}.rev".format(lang_code), "r").readlines()
	aligns_list = [i.replace("\n", "") for i in aligns_list]

	# Continue with processing the list to create the final alignments format which I'll use to correct proper names
	aligns_list = [i.split(" ") for i in aligns_list]

	for i in aligns_list:
		# If alignment line is empty, keep the dictionary empty
		if len(i) == 1 and len(i[0]) == 0:
			aligns_list[aligns_list.index(i)] = []
		else:
			for pair in i:
				current_pair = pair.split("-")
				i[i.index(pair)] = {int(current_pair[0]): int(current_pair[1])}
	
	final_aligns = []

	# Create a dictionary out of the rev alignments
	for i in aligns_list:
		current_line = {}

		try:
			for element in i:
				a = list(element.items())[0][0]
				b = list(element.items())[0][1]
				current_line[a] = b
		
			# Check whether the number of pairs in the list is the same as number of items
			if len(i) != len(list(current_line.items())):
				print("Not okay:")
				print(i)
				print(current_line)

			final_aligns.append(current_line)
		
		except:
			print("error")
			print(aligns_list.index(i))
			print(i)
			final_aligns.append("Error")
		
	print("\nNumber of aligned sentences: {}\n\n".format(len(final_aligns)))

	# Add a to the df
	df["alignments"] = final_aligns

	# When we open the dataframe file, the dictionaries with proper names changed into strings - Change strings in the column proper_nouns into dictionaries

	df["proper_nouns"] = df.proper_nouns.astype("str")
	df["proper_nouns"] = df.proper_nouns.apply(lambda x: ast.literal_eval(x))

	# Change nan values in the proper_nouns columns
	df = df.fillna(0)

	# Substitute words in the translation based on alignments
	intermediate_list = list(zip(df["translation-tokenized"], df["proper_nouns"], df["alignments"]))

	new_translations = []
	substituted_all_info = []
	substituted_only = []
	substituted_words = []

	# Add information whether an error occurred
	error_list = []

	for i in intermediate_list:
		current_substituted_list = []
		current_substituted_only = []
		current_substituted_words = {}
		current_error = "No"

		# If no proper names were detected, do not change the translation
		if i[1] == 0:
			new_translations.append(i[0])
		
		else:
			current_translation = i[0]

			# Substitute the word with the source lemma based on the index - loop through the proper nouns to be changed
			for word_index in list(i[1].keys()):
				try:
					# split the translation into list of words
					word_list = current_translation.split()

					# Get index of the substituted word
					substituted_word_index = i[2][word_index]

					# Get the lemma to substitute the word with
					correct_lemma = i[1][word_index][1]

					# If the substitute word and lemma are not the same, get substituted word and its match
					if word_list[substituted_word_index] != correct_lemma:
						current_substituted_list.append((word_list[substituted_word_index], correct_lemma))
						current_substituted_only.append((word_list[substituted_word_index], correct_lemma))

						# Save information on which word was substituted with its conllu index (index + 1) as the key
						current_substituted_words[int(substituted_word_index+1)] = word_list[substituted_word_index]

						# Substitute the word in the word list
						word_list[substituted_word_index] = correct_lemma
					
					else:
						# Add information that substitution was not performed
						current_substituted_list.append(f"No substitution: {word_list[substituted_word_index], correct_lemma}")
					
					# Change the translation by merging the words back into a string
					current_translation = " ".join(word_list)

				except:
					print(f"Issue: index {word_index}: {i[1][word_index]}")
					current_error = f"Issue: index {word_index}: {i[1][word_index]}"

			# After the loop through proper nouns, save the new translation
			new_translations.append(current_translation)
		
		# Add information on what was substituted
		if len(substituted_all_info) != 0:
			substituted_all_info.append(current_substituted_list)
		else:
			substituted_all_info.append(0)

		if len(current_substituted_only) != 0:
			substituted_only.append(current_substituted_only)
		else:
			substituted_only.append(0)

		error_list.append(current_error)

		substituted_words.append(current_substituted_words)


	# Add to the df
	df["new_translations"] = new_translations
	df["substitution_info"] = substituted_all_info
	df["substituted_pairs"] = substituted_only
	df["substituted_words"] = substituted_words
	df["errors"] = error_list

	end_time = round((time.time() - start_time)/60,2)

	print("Alignment completed. It took {} minutes.".format(end_time))

	# Change the working directory once again
	os.chdir("..")

	# Add the word list with indices to the df
	tokenized_text_list = df.tokenized_text.to_list()
	tokenized_text_list = [i.split(" ") for i in tokenized_text_list]
	tokenized_text_dict_list = []

	for sentence in tokenized_text_list:
		sentence_list = []
		counter = 1
		for word in sentence:
			sentence_list.append([word, counter])
			counter += 1
		tokenized_text_dict_list.append(sentence_list)

	df["source_indices"] = tokenized_text_dict_list

	# Save the df
	df.to_csv("{}".format(final_dataframe), sep="\t")

	# Display most common substitutions
	df_substituted = df[df["proper_nouns"] != "0"]
	print(df_substituted.substituted_pairs.value_counts()[:20].to_markdown())
	print("\n\n")

	return df

#df = tokenize_translation(translated_dataframe_path, #translated_tokenized_dataframe_path)

#print(df.head(3).to_markdown())
#print("\n\n")

df = correct_proper_nouns(translated_tokenized_dataframe_path, final_dataframe, lang_code)

# See if there were any errors in word substitution
print("Number of errors:")
print(df[df["errors"]!="No"].shape)
print("\n\n")

# See example of sentences with substituted words
print("Example of sentences with substituted words.")
print(df[df["substituted_pairs"]!= 0][:2].to_markdown())
# Out:
# Alignment started.
#
# Number of aligned sentences: 1804657
#
#
# Issue: index 1: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 50: ['.', '.']
# Issue: index 76: ['.', '.']
# Issue: index 35: ['Zaorálek', 'Zaorálek']
# Issue: index 24: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 29: ['-', '-']
# Issue: index 22: ['Faltýnka', 'Faltýnek']
# Issue: index 39: ['.', '.']
# Issue: index 21: ['Karel', 'Karel']
# Issue: index 18: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 6: ['-', '-']
# Issue: index 6: ['Pane', 'pan']
# Issue: index 15: ['po', 'po']
# Issue: index 7: ['Bakalovo', 'Bakalův']
# Issue: index 22: ['Bělobrádka', 'Bělobrádek']
# Issue: index 16: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 180: ['Volný', 'Volný']
# Issue: index 5: ['Kováčik', 'Kováčik']
# Issue: index 201: ['Volný', 'Volný']
# Issue: index 26: ['.', '.']
# Issue: index 28: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 0: ['Docházelo', 'docházet']
# Issue: index 0: ['Aha', 'aha']
# Issue: index 11: ['.', '.']
# Issue: index 4: ['Faltýnka', 'Faltýnek']
# Issue: index 10: ['.', '.']
# Issue: index 17: ['Kolovratník', 'Kolovratník']
# Issue: index 27: ['.', '.']
# Issue: index 32: ['.', '.']
# Issue: index 34: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 92: ['.', '.']
# Issue: index 36: ['.', '.']
# Issue: index 38: ['.', '.']
# Issue: index 112: ['.', '.']
# Issue: index 114: ['.', '.']
# Issue: index 61: ['.', '.']
# Issue: index 35: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 79: ['Faltýnek', 'Faltýnek']
# Issue: index 11: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 18: ['-', '-']
# Issue: index 15: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 33: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 2: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 37: ['.', '.']
# Issue: index 30: ['.', '.']
# Issue: index 57: ['.', '.']
# Issue: index 12: ['Richard', 'Richard']
# Issue: index 20: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 76: ['.', '.']
# Issue: index 7: ['Pane', 'pán']
# Issue: index 77: ['Dolejš', 'Dolejš']
# Issue: index 8: ['.', '.']
# Issue: index 5: ['A', 'A']
# Issue: index 6: ['.', '.']
# Issue: index 4: ['Vyzula', 'Vyzula']
# Issue: index 59: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 2: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 25: ['.', '.']
# Issue: index 32: ['.', '.']
# Issue: index 3: ['Kolovratník', 'Kolovratník']
# Issue: index 6: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 25: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 42: ['.', '.']
# Issue: index 49: ['.', '.']
# Issue: index 19: ['Si', 'Si']
# Issue: index 21: ['-', '-']
# Issue: index 3: ['.', '.']
# Issue: index 7: ['Pane', 'pan']
# Issue: index 23: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 48: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 238: ['Volný', 'Volný']
# Issue: index 18: ['K', 'K']
# Issue: index 28: ['K', 'K']
# Issue: index 7: ['K', 'K']
# Issue: index 12: ['de', 'de']
# Issue: index 13: ['-', '-']
# Issue: index 213: ['Skopeček', 'Skopeček']
# Issue: index 29: ['Chovance', 'Chovanec']
# Issue: index 33: ['Zaorálka', 'Zaorálek']
# Issue: index 7: ['Piráti', 'pirát']
# Issue: index 22: ['.', '.']
# Issue: index 38: ['.', '.']
# Issue: index 109: ['Sklenák', 'Sklenák']
# Issue: index 21: ['K', 'K']
# Issue: index 22: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 271: ['Květa', 'Květa']
# Issue: index 6: ['Chovance', 'Chovanec']
# Issue: index 8: ['Černochová', 'Černochová']
# Issue: index 6: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 15: ['O', 'O']
# Issue: index 16: ['.', '.']
# Issue: index 17: ['K', 'K']
# Issue: index 18: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 3: ['B', 'B']
# Issue: index 3: ['B', 'b']
# Issue: index 3: ['B', 'b']
# Issue: index 3: ['B', 'B']
# Issue: index 4: ['.', '.']
# Issue: index 11: ['Jiří', 'Jiří']
# Issue: index 8: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 34: ['.', '.']
# Issue: index 151: ['Podal', 'Podal']
# Issue: index 239: ['Zaorálek', 'Zaorálek']
# Issue: index 13: ['Volný', 'Volný']
# Issue: index 2: ['A', 'A']
# Issue: index 23: ['.', '.']
# Issue: index 25: ['.', '.']
# Issue: index 29: ['A', 'A']
# Issue: index 30: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 0: ['Vážený', 'vážený']
# Issue: index 11: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 30: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 26: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 33: ['pana', 'pan']
# Issue: index 25: ['.', '.']
# Issue: index 23: ['Kováčik', 'Kováčik']
# Issue: index 17: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 22: ['.', '.']
# Issue: index 28: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 37: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 22: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 39: ['.', '.']
# Issue: index 35: ['.', '.']
# Issue: index 1: ['Sklenák', 'Sklenák']
# Issue: index 0: ['Aleš', 'Aleš']
# Issue: index 40: ['.', '.']
# Issue: index 5: ['Faltýnek', 'Faltýnek']
# Issue: index 10: ['Faltýnka', 'Faltýnek']
# Issue: index 4: ['Nejedlý', 'Nejedlý']
# Issue: index 7: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 219: ['Podal', 'Podal']
# Issue: index 242: ['Podal', 'Podal']
# Issue: index 10: ['K', 'K']
# Issue: index 11: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 0: ['Mašek', 'Mašek']
# Issue: index 1: ['Jiří', 'Jiří']
# Issue: index 1: ['David', 'David']
# Issue: index 0: ['Zaorálek', 'Zaorálek']
# Issue: index 0: ['Zlesák', 'Zlesák']
# Issue: index 0: ['Bláha', 'Bláha']
# Issue: index 0: ['Dolejš', 'Dolejš']
# Issue: index 0: ['Holomčík', 'Holomčík']
# Issue: index 20: ['.', '.']
# Issue: index 22: ['.', '.']
# Issue: index 302: ['Volný', 'Volný']
# Issue: index 56: ['.', '.']
# Issue: index 64: ['.', '.']
# Issue: index 53: ['Andreje', 'Andrej']
# Issue: index 57: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 208: ['Podal', 'Podal']
# Issue: index 4: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 16: ['-', '-']
# Issue: index 7: ['Sklenák', 'Sklenák']
# Issue: index 3: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 28: ['.', '.']
# Issue: index 14: ['O', 'O']
# Issue: index 11: ['Faltýnka', 'Faltýnek']
# Issue: index 27: ['.', '.']
# Issue: index 26: ['Volný', 'Volný']
# Issue: index 0: ['Aby', 'aby']
# Issue: index 14: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 39: ['.', '.']
# Issue: index 41: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 30: ['.', '.']
# Issue: index 32: ['.', '.']
# Issue: index 56: ['.', '.']
# Issue: index 58: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 62: ['.', '.']
# Issue: index 67: ['.', '.']
# Issue: index 69: ['.', '.']
# Issue: index 47: ['.', '.']
# Issue: index 49: ['.', '.']
# Issue: index 36: ['.', '.']
# Issue: index 38: ['.', '.']
# Issue: index 78: ['.', '.']
# Issue: index 80: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 37: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 0: ['Hádky', 'hádka']
# Issue: index 20: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 78: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 98: ['Bláha', 'Bláha']
# Issue: index 7: ['Hamáčka', 'Hamáček']
# Issue: index 126: ['Faltýnek', 'Faltýnek']
# Issue: index 186: ['Jurečka', 'Jurečka']
# Issue: index 225: ['Jiří', 'Jiří']
# Issue: index 235: ['Kolovratník', 'Kolovratník']
# Issue: index 350: ['Julius', 'Julius']
# Issue: index 351: ['Špičák', 'Špičák']
# Issue: index 15: ['Skopeček', 'Skopeček']
# Issue: index 67: ['.', '.']
# Issue: index 69: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 2: ['Piráti', 'pirát']
# Issue: index 0: ['Aha', 'aha']
# Issue: index 6: ['Sklenáka', 'Sklenák']
# Issue: index 157: ['Rozvoral', 'Rozvoral']
# Issue: index 3: ['.', '.']
# Issue: index 17: ['Černochová', 'Černochová']
# Issue: index 29: ['.', '.']
# Issue: index 43: ['.', '.']
# Issue: index 45: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 2: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 7: ['Malé', 'Malá']
# Issue: index 22: ['Babiš', 'Babiš']
# Issue: index 14: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 174: ['Jiří', 'Jiří']
# Issue: index 45: ['.', '.']
# Issue: index 28: ['.', '.']
# Issue: index 14: ['K', 'K']
# Issue: index 15: ['.', '.']
# Issue: index 10: ['ANO', 'ANO']
# Issue: index 23: ['.', '.']
# Issue: index 31: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 6: ['Volný', 'Volný']
# Issue: index 14: ['Chovance', 'Chovanec']
# Issue: index 7: ['A', 'a']
# Issue: index 10: ['B', 'b']
# Issue: index 21: ['.', '.']
# Issue: index 26: ['.', '.']
# Issue: index 48: ['Stanjura', 'Stanjura']
# Issue: index 57: ['-', '-']
# Issue: index 23: ['-', '-']
# Issue: index 9: ['-', '-']
# Issue: index 5: ['-', '-']
# Issue: index 19: ['.', '.']
# Issue: index 2: ['-', '-']
# Issue: index 19: ['-', '-']
# Issue: index 28: ['-', '-']
# Issue: index 33: ['-', '-']
# Issue: index 21: ['-', '-']
# Issue: index 34: ['Si', 'Si']
# Issue: index 46: ['Si', 'Si']
# Issue: index 48: ['-', '-']
# Issue: index 37: ['-', '-']
# Issue: index 12: ['-', '-']
# Issue: index 2: ['-', '-']
# Issue: index 7: ['-', '-']
# Issue: index 2: ['-', '-']
# Issue: index 2: ['-', '-']
# Issue: index 12: ['Si', 'Si']
# Issue: index 14: ['-', '-']
# Issue: index 14: ['Si', 'Si']
# Issue: index 30: ['Si', 'Si']
# Issue: index 5: ['Si', 'Si']
# Issue: index 6: ['-', '-']
# Issue: index 0: ['Si', 'Si']
# Issue: index 2: ['-', '-']
# Issue: index 13: ['Si', 'Si']
# Issue: index 45: ['-', '-']
# Issue: index 2: ['-', '-']
# Issue: index 3: ['-', '-']
# Issue: index 2: ['-', '-']
# Issue: index 20: ['J', 'J']
# Issue: index 21: ['.', '.']
# Issue: index 51: ['.', '.']
# Issue: index 48: ['Zavadil', 'Zavadil']
# Issue: index 0: ['N', 'N']
# Issue: index 1: ['.', '.']
# Issue: index 2: ['I', 'I']
# Issue: index 3: ['.', '.']
# Issue: index 4: ['K', 'K']
# Issue: index 5: ['.', '.']
# Issue: index 6: ['D', 'D']
# Issue: index 7: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 22: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 30: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 16: ['-', '-']
# Issue: index 10: ['Babiš', 'Babiš']
# Issue: index 14: ['.', '.']
# Issue: index 22: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 36: ['Kolovratník', 'Kolovratník']
# Issue: index 14: ['.', '.']
# Issue: index 22: ['.', '.']
# Issue: index 22: ['.', '.']
# Issue: index 32: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 8: ['Izraelci', 'Izraelec']
# Issue: index 39: ['Ťok', 'Ťok']
# Issue: index 36: ['.', '.']
# Issue: index 41: ['.', '.']
# Issue: index 45: ['.', '.']
# Issue: index 54: ['.', '.']
# Issue: index 80: ['Černochová', 'Černochová']
# Issue: index 307: ['Jiří', 'Jiří']
# Issue: index 28: ['.', '.']
# Issue: index 30: ['.', '.']
# Issue: index 42: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 4: ['K', 'K']
# Issue: index 5: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 8: ['ANO', 'ANO']
# Issue: index 16: ['.', '.']
# Issue: index 37: ['.', '.']
# Issue: index 27: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 34: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 46: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 0: ['K', 'k']
# Issue: index 107: ['.', '.']
# Issue: index 17: ['Si', 'Si']
# Issue: index 7: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 5: ['Sklenáka', 'Sklenák']
# Issue: index 7: ['Si', 'Si']
# Issue: index 9: ['-', '-']
# Issue: index 18: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 0: ['Babiš', 'Babiš']
# Issue: index 12: ['.', '.']
# Issue: index 1: ['Pane', 'pán']
# Issue: index 26: ['.', '.']
# Issue: index 28: ['.', '.']
# Issue: index 39: ['.', '.']
# Issue: index 41: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 26: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 23: ['D', 'D']
# Issue: index 24: ['.', '.']
# Issue: index 26: ['.', '.']
# Issue: index 18: ['H', 'H']
# Issue: index 19: ['.', '.']
# Issue: index 8: ['Sklenák', 'Sklenák']
# Issue: index 11: ['Zavadil', 'Zavadil']
# Issue: index 20: ['.', '.']
# Issue: index 22: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 49: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 49: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 2: ['.', '.']
# Issue: index 26: ['.', '.']
# Issue: index 36: ['.', '.']
# Issue: index 0: ['Zaorálka', 'Zaorálek']
# Issue: index 94: ['X', 'X']
# Issue: index 95: ['.', '.']
# Issue: index 10: ['A', 'A']
# Issue: index 11: ['.', '.']
# Issue: index 12: ['V', 'V']
# Issue: index 13: ['.', '.']
# Issue: index 3: ['A', 'A']
# Issue: index 4: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 15: ['A', 'A']
# Issue: index 16: ['.', '.']
# Issue: index 18: ['A', 'A']
# Issue: index 19: ['.', '.']
# Issue: index 20: ['V', 'V']
# Issue: index 13: ['Ťok', 'Ťok']
# Issue: index 9: ['Bělobrádka', 'Bělobrádek']
# Issue: index 6: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 0: ['U', 'u']
# Issue: index 6: ['G', 'G']
# Issue: index 3: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 27: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 27: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 17: ['Faltýnek', 'Faltýnek']
# Issue: index 253: ['Síla', 'Síla']
# Issue: index 108: ['Dražilová', 'Dražilová']
# Issue: index 40: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 22: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 51: ['Andreje', 'Andrej']
# Issue: index 6: ['.', '.']
# Issue: index 3: ['K', 'K']
# Issue: index 4: ['.', '.']
# Issue: index 40: ['Petra', 'Petr']
# Issue: index 36: ['O', 'o']
# Issue: index 37: ['.', '.']
# Issue: index 38: ['K', 'K']
# Issue: index 39: ['.', '.']
# Issue: index 88: ['O', 'o']
# Issue: index 89: ['.', '.']
# Issue: index 43: ['.', '.']
# Issue: index 48: ['O', 'O']
# Issue: index 49: ['.', '.']
# Issue: index 50: ['K', 'K']
# Issue: index 12: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 35: ['Petra', 'Petr']
# Issue: index 5: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 20: ['Špičák', 'Špičák']
# Issue: index 52: ['.', '.']
# Issue: index 57: ['.', '.']
# Issue: index 0: ['O', 'O']
# Issue: index 1: ['.', '.']
# Issue: index 2: ['K', 'K']
# Issue: index 3: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 9: ['natvrdo', 'natvrdo']
# Issue: index 43: ['O', 'O']
# Issue: index 44: ['.', '.']
# Issue: index 46: ['.', '.']
# Issue: index 1: ['O', 'O']
# Issue: index 2: ['.', '.']
# Issue: index 3: ['K', 'K']
# Issue: index 4: ['.', '.']
# Issue: index 22: ['Vítem', 'Vít']
# Issue: index 7: ['Si', 'Si']
# Issue: index 5: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 208: ['Tom', 'Tom']
# Issue: index 14: ['Babiš', 'Babiš']
# Issue: index 1: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 27: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 15: ['Volný', 'Volný']
# Issue: index 1: ['Žáček', 'Žáček']
# Issue: index 1: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 12: ['Síla', 'Síla']
# Issue: index 53: ['Pirátům', 'pirát']
# Issue: index 24: ['Vítem', 'Vít']
# Issue: index 197: ['Síla', 'Síla']
# Issue: index 11: ['ANO', 'ANO']
# Issue: index 6: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 70: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 7: ['Andreje', 'Andrej']
# Issue: index 4: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 3: ['B', 'b']
# Issue: index 4: ['.', '.']
# Issue: index 5: ['d', 'd']
# Issue: index 11: ['.', '.']
# Issue: index 7: ['Vítem', 'Vít']
# Issue: index 1: ['Milan', 'Milan']
# Issue: index 0: ['Flek', 'Flek']
# Issue: index 1: ['Josef', 'Josef']
# Issue: index 1: ['Josef', 'Josef']
# Issue: index 0: ['Pošarová', 'Pošarová']
# Issue: index 1: ['Marie', 'Marie']
# Issue: index 1: ['David', 'David']
# Issue: index 0: ['Stržínek', 'Stržínek']
# Issue: index 1: ['Karel', 'Karel']
# Issue: index 13: ['Babiš', 'Babiš']
# Issue: index 52: ['Dostálová', 'Dostálová']
# Issue: index 63: ['Aleš', 'Aleš']
# Issue: index 72: ['Milan', 'Milan']
# Issue: index 91: ['Josef', 'Josef']
# Issue: index 165: ['David', 'David']
# Issue: index 184: ['Kolovratník', 'kolovratník']
# Issue: index 319: ['Pošarová', 'Pošarová']
# Issue: index 5: ['.', '.']
# Issue: index 160: ['Kolovratník', 'Kolovratník']
# Issue: index 24: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 18: ['Aleš', 'Aleš']
# Issue: index 48: ['Stanjura', 'Stanjura']
# Issue: index 0: ['Babiš', 'Babiš']
# Issue: index 17: ['Petra', 'Petr']
# Issue: index 31: ['Faltýnek', 'Faltýnek']
# Issue: index 1: ['O', 'O']
# Issue: index 2: ['.', '.']
# Issue: index 3: ['K', 'K']
# Issue: index 4: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 7: ['Si', 'Si']
# Issue: index 9: ['-', '-']
# Issue: index 0: ['Skopeček', 'Skopeček']
# Issue: index 0: ['Dražilová', 'Dražilová']
# Issue: index 1: ['Lenka', 'Lenka']
# Issue: index 8: ['Dostálová', 'Dostálová']
# Issue: index 139: ['Faltýnek', 'Faltýnek']
# Issue: index 244: ['Aleš', 'Aleš']
# Issue: index 13: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 8: ['O', 'O']
# Issue: index 9: ['.', '.']
# Issue: index 10: ['K', 'K']
# Issue: index 11: ['.', '.']
# Issue: index 27: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 0: ['O', 'O']
# Issue: index 1: ['.', '.']
# Issue: index 2: ['K', 'K']
# Issue: index 3: ['.', '.']
# Issue: index 9: ['-', '-']
# Issue: index 116: ['Faltýnek', 'Faltýnek']
# Issue: index 178: ['.', '.']
# Issue: index 356: ['K', 'K']
# Issue: index 357: ['.', '.']
# Issue: index 362: ['.', '.']
# Issue: index 364: ['.', '.']
# Issue: index 367: ['.', '.']
# Issue: index 369: ['.', '.']
# Issue: index 5: ['Z', 'Z']
# Issue: index 7: ['K', 'K']
# Issue: index 8: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 136: ['K', 'K']
# Issue: index 224: ['Z', 'Z']
# Issue: index 226: ['K', 'K']
# Issue: index 242: ['.', '.']
# Issue: index 244: ['.', '.']
# Issue: index 263: ['.', '.']
# Issue: index 265: ['.', '.']
# Issue: index 288: ['.', '.']
# Issue: index 290: ['.', '.']
# Issue: index 363: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 105: ['Z', 'Z']
# Issue: index 107: ['K', 'K']
# Issue: index 116: ['V', 'V']
# Issue: index 118: ['K', 'K']
# Issue: index 122: ['.', '.']
# Issue: index 124: ['.', '.']
# Issue: index 126: ['.', '.']
# Issue: index 130: ['V', 'V']
# Issue: index 131: ['.', '.']
# Issue: index 135: ['.', '.']
# Issue: index 158: ['K', 'K']
# Issue: index 165: ['F', 'F']
# Issue: index 171: ['.', '.']
# Issue: index 216: ['.', '.']
# Issue: index 235: ['K', 'K']
# Issue: index 239: ['.', '.']
# Issue: index 243: ['.', '.']
# Issue: index 246: ['.', '.']
# Issue: index 248: ['.', '.']
# Issue: index 352: ['.', '.']
# Issue: index 354: ['.', '.']
# Issue: index 371: ['Z', 'Z']
# Issue: index 372: ['.', '.']
# Issue: index 373: ['K', 'K']
# Issue: index 379: ['.', '.']
# Issue: index 381: ['.', '.']
# Issue: index 384: ['.', '.']
# Issue: index 386: ['.', '.']
# Issue: index 393: ['.', '.']
# Issue: index 148: ['Z', 'Z']
# Issue: index 149: ['.', '.']
# Issue: index 150: ['K', 'K']
# Issue: index 154: ['.', '.']
# Issue: index 156: ['.', '.']
# Issue: index 196: ['.', '.']
# Issue: index 265: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 46: ['K', 'K']
# Issue: index 53: ['K', 'K']
# Issue: index 54: ['.', '.']
# Issue: index 194: ['N', 'N']
# Issue: index 201: ['N', 'N']
# Issue: index 207: ['.', '.']
# Issue: index 218: ['.', '.']
# Issue: index 219: ['K', 'K']
# Issue: index 250: ['.', '.']
# Issue: index 255: ['.', '.']
# Issue: index 260: ['.', '.']
# Issue: index 58: ['.', '.']
# Issue: index 92: ['.', '.']
# Issue: index 116: ['.', '.']
# Issue: index 118: ['.', '.']
# Issue: index 152: ['.', '.']
# Issue: index 177: ['.', '.']
# Issue: index 179: ['.', '.']
# Issue: index 222: ['.', '.']
# Issue: index 224: ['.', '.']
# Issue: index 351: ['.', '.']
# Issue: index 353: ['.', '.']
# Issue: index 363: ['.', '.']
# Issue: index 368: ['.', '.']
# Issue: index 39: ['.', '.']
# Issue: index 44: ['.', '.']
# Issue: index 51: ['.', '.']
# Issue: index 52: ['K', 'K']
# Issue: index 53: ['.', '.']
# Issue: index 143: ['.', '.']
# Issue: index 145: ['.', '.']
# Issue: index 223: ['.', '.']
# Issue: index 226: ['.', '.']
# Issue: index 228: ['.', '.']
# Issue: index 244: ['.', '.']
# Issue: index 253: ['.', '.']
# Issue: index 254: ['K', 'K']
# Issue: index 255: ['.', '.']
# Issue: index 276: ['.', '.']
# Issue: index 361: ['.', '.']
# Issue: index 368: ['.', '.']
# Issue: index 370: ['.', '.']
# Issue: index 373: ['.', '.']
# Issue: index 375: ['.', '.']
# Issue: index 246: ['.', '.']
# Issue: index 258: ['.', '.']
# Issue: index 260: ['.', '.']
# Issue: index 263: ['.', '.']
# Issue: index 265: ['.', '.']
# Issue: index 185: ['.', '.']
# Issue: index 195: ['.', '.']
# Issue: index 197: ['.', '.']
# Issue: index 199: ['.', '.']
# Issue: index 202: ['.', '.']
# Issue: index 204: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 104: ['.', '.']
# Issue: index 106: ['.', '.']
# Issue: index 116: ['.', '.']
# Issue: index 118: ['.', '.']
# Issue: index 336: ['.', '.']
# Issue: index 338: ['.', '.']
# Issue: index 341: ['.', '.']
# Issue: index 343: ['.', '.']
# Issue: index 69: ['.', '.']
# Issue: index 71: ['.', '.']
# Issue: index 208: ['.', '.']
# Issue: index 298: ['N', 'N']
# Issue: index 304: ['.', '.']
# Issue: index 306: ['.', '.']
# Issue: index 311: ['.', '.']
# Issue: index 7: ['Z', 'Z']
# Issue: index 9: ['K', 'K']
# Issue: index 10: ['.', '.']
# Issue: index 21: ['P', 'P']
# Issue: index 26: ['K', 'K']
# Issue: index 37: ['.', '.']
# Issue: index 42: ['.', '.']
# Issue: index 45: ['.', '.']
# Issue: index 47: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 10: ['F', 'F']
# Issue: index 11: ['.', '.']
# Issue: index 57: ['.', '.']
# Issue: index 59: ['.', '.']
# Issue: index 29: ['Rozvoral', 'Rozvoral']
# Issue: index 0: ['O', 'o']
# Issue: index 1: ['.', '.']
# Issue: index 2: ['k', 'k']
# Issue: index 3: ['.', '.']
# Issue: index 50: ['Kolovratník', 'Kolovratník']
# Issue: index 8: ['.', '.']
# Issue: index 2: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 4: ['ANO', 'ANO']
# Issue: index 32: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 11: ['Zavadil', 'Zavadil']
# Issue: index 10: ['.', '.']
# Issue: index 11: ['A', 'A']
# Issue: index 12: ['.', '.']
# Issue: index 25: ['.', '.']
# Issue: index 26: ['A', 'A']
# Issue: index 27: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 11: ['Kolovratník', 'Kolovratník']
# Issue: index 13: ['Bělobrádka', 'Bělobrádek']
# Issue: index 12: ['Milan', 'Milan']
# Issue: index 36: ['.', '.']
# Issue: index 19: ['d', 'd']
# Issue: index 14: ['C', 'C']
# Issue: index 15: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 16: ['dnes', 'dnes']
# Issue: index 10: ['Jiří', 'Jiří']
# Issue: index 45: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 2: ['Z', 'Z']
# Issue: index 3: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 2: ['K', 'K']
# Issue: index 3: ['.', '.']
# Issue: index 6: ['Hamáčkovi', 'Hamáček']
# Issue: index 27: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 45: ['-', '-']
# Issue: index 22: ['-', '-']
# Issue: index 346: ['Zavadil', 'Zavadil']
# Issue: index 27: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 25: ['.', '.']
# Issue: index 25: ['A', 'A']
# Issue: index 26: ['.', '.']
# Issue: index 27: ['S', 'S']
# Issue: index 28: ['.', '.']
# Issue: index 32: ['I', 'I']
# Issue: index 33: ['.', '.']
# Issue: index 35: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 54: ['.', '.']
# Issue: index 19: ['Z', 'Z']
# Issue: index 20: ['.', '.']
# Issue: index 345: ['Volný', 'Volný']
# Issue: index 18: ['Ťok', 'Ťok']
# Issue: index 17: ['.', '.']
# Issue: index 18: ['A', 'A']
# Issue: index 19: ['.', '.']
# Issue: index 45: ['.', '.']
# Issue: index 47: ['.', '.']
# Issue: index 50: ['.', '.']
# Issue: index 10: ['Babiš', 'Babiš']
# Issue: index 15: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 5: ['Stanjura', 'Stanjura']
# Issue: index 2: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 16: ['-', '-']
# Issue: index 28: ['-', '-']
# Issue: index 6: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 25: ['.', '.']
# Issue: index 32: ['dr', 'doktor']
# Issue: index 33: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 26: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 26: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 25: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 7: ['A', 'a']
# Issue: index 4: ['.', '.']
# Issue: index 45: ['Zaorálek', 'Zaorálek']
# Issue: index 7: ['Sklenáka', 'Sklenák']
# Issue: index 12: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 38: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 110: ['Jurečky', 'Jurečka']
# Issue: index 11: ['Pane', 'pán']
# Issue: index 38: ['A', 'A']
# Issue: index 39: ['.', '.']
# Issue: index 41: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 14: ['Zaorálka', 'Zaorálek']
# Issue: index 14: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 55: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 37: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 41: ['O', 'O']
# Issue: index 133: ['Kolovratník', 'Kolovratník']
# Issue: index 19: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 32: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 5: ['ANO', 'ANO']
# Issue: index 13: ['.', '.']
# Issue: index 27: ['.', '.']
# Issue: index 117: ['Černochová', 'Černochová']
# Issue: index 51: ['.', '.']
# Issue: index 1: ['-', '-']
# Issue: index 48: ['.', '.']
# Issue: index 53: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 38: ['Svoboda', 'Svoboda']
# Issue: index 2: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 270: ['Sklenák', 'Sklenák']
# Issue: index 29: ['.', '.']
# Issue: index 32: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 9: ['s', 's']
# Issue: index 11: ['E', 'E']
# Issue: index 153: ['Stržínek', 'Stržínek']
# Issue: index 14: ['Kolovratník', 'Kolovratník']
# Issue: index 12: ['Kolovratník', 'kolovratník']
# Issue: index 18: ['.', '.']
# Issue: index 19: ['K', 'K']
# Issue: index 20: ['.', '.']
# Issue: index 14: ['Zaorálka', 'Zaorálek']
# Issue: index 10: ['Stanjura', 'Stanjura']
# Issue: index 22: ['O', 'O']
# Issue: index 23: ['.', '.']
# Issue: index 24: ['K', 'K']
# Issue: index 25: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 2: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 17: ['Robert', 'Robert']
# Issue: index 22: ['Černochové', 'Černochová']
# Issue: index 13: ['.', '.']
# Issue: index 15: ['STAN', 'STAN']
# Issue: index 29: ['d', 'd']
# Issue: index 30: ["'", "'"]
# Issue: index 0: ['Hájka', 'Hájka']
# Issue: index 30: ['Jak', 'Jak']
# Issue: index 41: ['.', '.']
# Issue: index 219: ['Podal', 'Podal']
# Issue: index 15: ['Hamáčkovi', 'Hamáček']
# Issue: index 10: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 27: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 12: ['D', 'D']
# Issue: index 10: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 40: ['.', '.']
# Issue: index 42: ['.', '.']
# Issue: index 53: ['.', '.']
# Issue: index 55: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 11: ['32', '32']
# Issue: index 5: ['Kolovratník', 'Kolovratník']
# Issue: index 47: ['O', 'O']
# Issue: index 48: ['.', '.']
# Issue: index 49: ['K', 'K']
# Issue: index 50: ['.', '.']
# Issue: index 10: ['Faltýnek', 'Faltýnek']
# Issue: index 204: ['Podal', 'Podal']
# Issue: index 4: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 34: ['.', '.']
# Issue: index 36: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 0: ['O', 'O']
# Issue: index 1: ['.', '.']
# Issue: index 2: ['K', 'K']
# Issue: index 3: ['.', '.']
# Issue: index 34: ['.', '.']
# Issue: index 36: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 25: ['D', 'D']
# Issue: index 26: ['.', '.']
# Issue: index 201: ['Lenka', 'Lenka']
# Issue: index 268: ['Podal', 'Podal']
# Issue: index 9: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 21: ['Pirátů', 'pirát']
# Issue: index 18: ['E', 'E']
# Issue: index 19: ['.', '.']
# Issue: index 20: ['E', 'e']
# Issue: index 22: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 11: ['d', 'd']
# Issue: index 281: ['Podal', 'Podal']
# Issue: index 0: ['Aby', 'aby']
# Issue: index 1: ['bychom', 'být']
# Issue: index 9: ['J', 'J']
# Issue: index 8: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 26: ['.', '.']
# Issue: index 34: ['.', '.']
# Issue: index 36: ['.', '.']
# Issue: index 39: ['.', '.']
# Issue: index 46: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 25: ['D', 'D']
# Issue: index 30: ['Hamáčka', 'Hamáček']
# Issue: index 16: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 12: ['Kolovratník', 'Kolovratník']
# Issue: index 6: ['O', 'O']
# Issue: index 8: ['K', 'K']
# Issue: index 26: ['Andreje', 'Andrej']
# Issue: index 47: ['.', '.']
# Issue: index 51: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 11: ['Podal', 'Podal']
# Issue: index 7: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 25: ['.', '.']
# Issue: index 27: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 31: ['.', '.']
# Issue: index 8: ['Volný', 'Volný']
# Issue: index 10: ['Volný', 'Volný']
# Issue: index 4: ['V', 'V']
# Issue: index 10: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 11: ['O', 'o']
# Issue: index 12: ['.', '.']
# Issue: index 13: ['K', 'k']
# Issue: index 14: ['.', '.']
# Issue: index 0: ['Zagonguji', 'zagongovat']
# Issue: index 30: ['.', '.']
# Issue: index 32: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 26: ['.', '.']
# Issue: index 36: ['.', '.']
# Issue: index 38: ['.', '.']
# Issue: index 47: ['.', '.']
# Issue: index 57: ['.', '.']
# Issue: index 59: ['.', '.']
# Issue: index 71: ['.', '.']
# Issue: index 73: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 18: ['D', 'D']
# Issue: index 18: ['Hamáčka', 'Hamáček']
# Issue: index 1: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 26: ['.', '.']
# Issue: index 28: ['.', '.']
# Issue: index 11: ['SÚKL', 'SÚKL']
# Issue: index 23: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 2: ['O', 'O']
# Issue: index 5: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 30: ['.', '.']
# Issue: index 37: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 3: ['K', 'K']
# Issue: index 5: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 25: ['.', '.']
# Issue: index 20: ['Sklenák', 'Sklenák']
# Issue: index 9: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 14: ['Faltýnka', 'Faltýnek']
# Issue: index 6: ['O', 'o']
# Issue: index 7: ['.', '.']
# Issue: index 8: ['K', 'K']
# Issue: index 9: ['.', '.']
# Issue: index 39: ['-', '-']
# Issue: index 1: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 5: ['Volný', 'Volný']
# Issue: index 24: ['.', '.']
# Issue: index 34: ['.', '.']
# Issue: index 64: ['.', '.']
# Issue: index 11: ['Pan', 'pan']
# Issue: index 17: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 36: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 44: ['.', '.']
# Issue: index 26: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 167: ['Ťok', 'Ťok']
# Issue: index 17: ['Ťok', 'Ťok']
# Issue: index 21: ['.', '.']
# Issue: index 39: ['.', '.']
# Issue: index 34: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 2: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 37: ['.', '.']
# Issue: index 22: ['Faltýnek', 'Faltýnek']
# Issue: index 7: ['.', '.']
# Issue: index 42: ['.', '.']
# Issue: index 47: ['.', '.']
# Issue: index 52: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 26: ['.', '.']
# Issue: index 2: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 52: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 20: ['Ťok', 'Ťok']
# Issue: index 21: ['.', '.']
# Issue: index 0: ['Zaorálka', 'Zaorálek']
# Issue: index 3: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 29: ['.', '.']
# Issue: index 65: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 16: ['Chovance', 'Chovanec']
# Issue: index 1: ['paní', 'paní']
# Issue: index 5: ['.', '.']
# Issue: index 6: ['Volný', 'Volný']
# Issue: index 15: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 47: ['.', '.']
# Issue: index 49: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 32: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 7: ['Babiš', 'Babiš']
# Issue: index 33: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 34: ['Volný', 'Volný']
# Issue: index 28: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 57: ['.', '.']
# Issue: index 9: ['Zavadil', 'Zavadil']
# Issue: index 58: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 10: ['C', 'c']
# Issue: index 23: ['.', '.']
# Issue: index 32: ['.', '.']
# Issue: index 12: ['Zaorálka', 'Zaorálek']
# Issue: index 5: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 36: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 14: ['t', 'tento']
# Issue: index 15: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 35: ['.', '.']
# Issue: index 28: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 23: ['Jurečka', 'Jurečka']
# Issue: index 4: ['.', '.']
# Issue: index 31: ['dr', 'doktor']
# Issue: index 32: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 10: ['Faltýnek', 'Faltýnek']
# Issue: index 16: ['.', '.']
# Issue: index 17: ['Jurečka', 'Jurečka']
# Issue: index 72: ['.', '.']
# Issue: index 80: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 15: ['Pražané', 'Pražan']
# Issue: index 24: ['.', '.']
# Issue: index 81: ['Podal', 'Podal']
# Issue: index 28: ['Jurečky', 'Jurečka']
# Issue: index 12: ['Zase', 'zase']
# Issue: index 1: ['-', '-']
# Issue: index 9: ['-', '-']
# Issue: index 2: ['-', '-']
# Issue: index 15: ['.', '.']
# Issue: index 38: ['Malá', 'Malá']
# Issue: index 60: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 65: ['.', '.']
# Issue: index 13: ['Vítem', 'Vít']
# Issue: index 8: ['.', '.']
# Issue: index 2: ['Běhounku', 'Běhounka']
# Issue: index 2: ['.', '.']
# Issue: index 58: ['Havrdová', 'Havrdová']
# Issue: index 7: ['K', 'K']
# Issue: index 4: ['K', 'K']
# Issue: index 13: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 20: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 13: ['K', 'K']
# Issue: index 14: ['.', '.']
# Issue: index 13: ['Černochová', 'Černochová']
# Issue: index 12: ['.', '.']
# Issue: index 34: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 23: ['Faltýnek', 'Faltýnek']
# Issue: index 22: ['.', '.']
# Issue: index 158: ['Sklenák', 'Sklenák']
# Issue: index 14: ['.', '.']
# Issue: index 22: ['.', '.']
# Issue: index 9: ['-', '-']
# Issue: index 0: ['Aby', 'aby']
# Issue: index 1: ['bych', 'být']
# Issue: index 8: ['.', '.']
# Issue: index 262: ['Sklenák', 'Sklenák']
# Issue: index 15: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 22: ['.', '.']
# Issue: index 24: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 25: ['.', '.']
# Issue: index 15: ['Bělobrádka', 'Bělobrádek']
# Issue: index 15: ['.', '.']
# Issue: index 14: ['Hamáčka', 'Hamáček']
# Issue: index 168: ['Richard', 'Richard']
# Issue: index 7: ['Podala', 'Podal']
# Issue: index 23: ['Černohorský', 'Černohorský']
# Issue: index 39: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 23: ['.', '.']
# Issue: index 16: ['Dr', 'doktor']
# Issue: index 17: ['.', '.']
# Issue: index 33: ['.', '.']
# Issue: index 35: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 0: ['O', 'O']
# Issue: index 2: ['k', 'k']
# Issue: index 3: ['.', '.']
# Issue: index 6: ['G', 'G']
# Issue: index 7: ['.', '.']
# Issue: index 8: ['K', 'K']
# Issue: index 9: ['.', '.']
# Issue: index 7: ['-', '-']
# Issue: index 8: ['-', '-']
# Issue: index 7: ['-', '-']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 5: ['ANO', 'ANO']
# Issue: index 0: ['Pohříchu', 'pohříchu']
# Issue: index 34: ['.', '.']
# Issue: index 3: ['K', 'K']
# Issue: index 4: ['.', '.']
# Issue: index 6: ['K', 'K']
# Issue: index 16: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 8: ['Černochová', 'Černochová']
# Issue: index 7: ['.', '.']
# Issue: index 2: ['O', 'O']
# Issue: index 3: ['.', '.']
# Issue: index 4: ['K', 'K']
# Issue: index 5: ['.', '.']
# Issue: index 12: ['J', 'J']
# Issue: index 21: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 18: ['Vondráčka', 'Vondráček']
# Issue: index 5: ['Hamáčkovi', 'Hamáček']
# Issue: index 22: ['.', '.']
# Issue: index 8: ['-', '-']
# Issue: index 31: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 3: ['Senát', 'senát']
# Issue: index 4: ['Bělobrádka', 'Bělobrádek']
# Issue: index 16: ['.', '.']
# Issue: index 18: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 19: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 25: ['.', '.']
# Issue: index 2: ['.', '.']
# Issue: index 1: ['Dolejš', 'Dolejš']
# Issue: index 1: ['Hyťhová', 'Hyťhová']
# Issue: index 0: ['Aleš', 'Aleš']
# Issue: index 1: ['Mališ', 'Mališ']
# Issue: index 0: ['Květa', 'Květa']
# Issue: index 1: ['Špičák', 'Špičák']
# Issue: index 0: ['Jiří', 'Jiří']
# Issue: index 10: ['.', '.']
# Issue: index 0: ['N', 'n']
# Issue: index 0: ['N', 'N']
# Issue: index 0: ['N', 'n']
# Issue: index 12: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 0: ['N', 'n']
# Issue: index 26: ['.', '.']
# Issue: index 50: ['.', '.']
# Issue: index 52: ['.', '.']
# Issue: index 58: ['Brázdil', 'Brázdil']
# Issue: index 65: ['Černohorský', 'Černohorský']
# Issue: index 76: ['Dražilová', 'Dražilová']
# Issue: index 91: ['Faltýnek', 'Faltýnek']
# Issue: index 153: ['Hyťhová', 'Hyťhová']
# Issue: index 399: ['Zaorálek', 'Zaorálek']
# Issue: index 137: ['Černohorský', 'Černohorský']
# Issue: index 3: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 1: ['Baxa', 'Baxa']
# Issue: index 3: ['B', 'B']
# Issue: index 29: ['Babiš', 'Babiš']
# Issue: index 12: ['-', '-']
# Issue: index 2: ['-', '-']
# Issue: index 33: ['.', '.']
# Issue: index 35: ['.', '.']
# Issue: index 197: ['Zaorálek', 'Zaorálek']
# Issue: index 0: ['A', 'a']
# Issue: index 1: ['.', '.']
# Issue: index 2: ['A', 'a']
# Issue: index 10: ['N', 'N']
# Issue: index 8: ['.', '.']
# Issue: index 9: ['A', 'A']
# Issue: index 3: ['A', 'A']
# Issue: index 4: ['.', '.']
# Issue: index 5: ['B', 'B']
# Issue: index 6: ['.', '.']
# Issue: index 3: ['A', 'A']
# Issue: index 4: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 178: ['Podal', 'Podal']
# Issue: index 6: ['.', '.']
# Issue: index 7: ['N', 'N']
# Issue: index 8: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 22: ['N', 'N']
# Issue: index 21: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 21: ['.', '.']
# Issue: index 84: ['Bláha', 'Bláha']
# Issue: index 215: ['Kolovratník', 'Kolovratník']
# Issue: index 252: ['Matyášová', 'Matyášová']
# Issue: index 379: ['Volný', 'Volný']
# Issue: index 0: ['N', 'N']
# Issue: index 0: ['N', 'N']
# Issue: index 9: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 9: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 14: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 4: ['.', '.']
# Issue: index 15: ['Piráti', 'pirát']
# Issue: index 1: ['.', '.']
# Issue: index 16: ['Dostálová', 'Dostálová']
# Issue: index 21: ['.', '.']
# Issue: index 1: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 28: ['.', '.']
# Issue: index 13: ['Metnara', 'Metnar']
# Issue: index 5: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 3: ['.', '.']
# Issue: index 41: ['Rozvoral', 'Rozvoral']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 3: ['Z', 'Z']
# Issue: index 5: ['V', 'V']
# Issue: index 10: ['Jurečka', 'Jurečka']
# Issue: index 32: ['ANO', 'ANO']
# Issue: index 7: ['Hrehovo', 'Hrehův']
# Issue: index 16: ['.', '.']
# Issue: index 5: ['.', '.']
# Issue: index 17: ['.', '.']
# Issue: index 35: ['.', '.']
# Issue: index 100: ['.', '.']
# Issue: index 7: ['.', '.']
# Issue: index 13: ['.', '.']
# Issue: index 21: ['-', '-']
# Issue: index 1: ['-', '-']
# Issue: index 73: ['Rozvoral', 'Rozvoral']
# Issue: index 113: ['Aleš', 'Aleš']
# Issue: index 14: ['Baxa', 'Baxa']
# Issue: index 0: ['Vážený', 'vážený']
# Issue: index 0: ['Holt', 'holt']
# Issue: index 2: ['.', '.']
# Issue: index 48: ['.', '.']
# Issue: index 55: ['.', '.']
# Issue: index 83: ['.', '.']
# Issue: index 0: ['N', 'N']
# Issue: index 0: ['N', 'N']
# Issue: index 0: ['N', 'n']
# Issue: index 0: ['N', 'n']
# Issue: index 0: ['N', 'n']
# Issue: index 0: ['N', 'N']
# Issue: index 0: ['N', 'n']
# Issue: index 0: ['N', 'N']
# Issue: index 0: ['N', 'N']
# Issue: index 0: ['N', 'n']
# Issue: index 0: ['N', 'N']
# Issue: index 0: ['N', 'n']
# Issue: index 0: ['N', 'n']
# Issue: index 0: ['N', 'n']
# Issue: index 0: ['N', 'n']
# Issue: index 19: ['.', '.']
# Issue: index 7: ['K', 'K']
# Issue: index 8: ['.', '.']
# Issue: index 10: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 8: ['.', '.']
# Issue: index 28: ['.', '.']
# Issue: index 6: ['.', '.']
# Issue: index 15: ['.', '.']
# Issue: index 8: ['Černochové', 'Černochová']
# Issue: index 4: ['.', '.']
# Issue: index 11: ['.', '.']
# Issue: index 16: ['.', '.']
# Issue: index 228: ['Květa', 'Květa']
# Issue: index 352: ['Vyzula', 'Vyzula']
# Issue: index 361: ['Zlesák', 'Zlesák']
# Issue: index 6: ['.', '.']
# Issue: index 12: ['.', '.']
# Issue: index 22: ['Výborný', 'Výborný']
# Issue: index 65: ['Brázdil', 'Brázdil']
# Issue: index 233: ['Matyášová', 'Matyášová']
# Issue: index 17: ['A', 'a']
# Issue: index 31: ['-', '-']
# Issue: index 20: ['Josef', 'Josef']
# Issue: index 26: ['.', '.']
# Issue: index 28: ['.', '.']
# Issue: index 32: ['.', '.']
# Issue: index 1: ['-', '-']
# Issue: index 1: ['.', '.']
# Alignment completed. It took 12.32 minutes.
# |                               |   substituted_pairs |
# |:------------------------------|--------------------:|
# | 0                             |         1.72096e+06 |
# | [('Faltynek', 'Faltýnek')]    |      2423           |
# | [('Andrei', 'Andrej')]        |      2051           |
# | [('Schiller', 'Schillerová')] |      1902           |
# | [('Pirates', 'pirát')]        |      1289           |
# | [('Richter', 'Richterová')]   |      1210           |
# | [('Laudat', 'Laudát')]        |      1208           |
# | [('Free', 'Volný')]           |      1187           |
# | [('Excellent', 'Výborný')]    |      1086           |
# | [('Austrian', 'Rakušan')]     |       964           |
# | [('Peter', 'Petr')]           |       841           |
# | [('Michalek', 'Michálek')]    |       716           |
# | [('Philip', 'Filip')]         |       633           |
# | [('Mark', 'Marek')]           |       557           |
# | [('Wark', 'Válková')]         |       547           |
# | [('Vera', 'Věra')]            |       438           |
# | [('Kaňkovsky', 'Kaňkovský')]  |       436           |
# | [('Pastuch', 'Pastuchová')]   |       434           |
# | [('Zaoralek', 'Zaorálek')]    |       426           |
# | [('Marks', 'Marksová')]       |       420           |
#
#
#
# Number of errors:
# (1086, 19)
#
#
#
# Example of sentences with substituted words.
# |    | file_path                                                                                                                                       | file                                                 | sentence_id                                            | text                                                                                                                           | tokenized_text                                                                                                                      | proper_nouns                                                   |   length | translation                                                                                                                          | translation-tokenized                                                                                                                 | space-after-information                                                                                                                                                  | fwd_align_dict                                                                                                                                                                                   | bwd_align_dict                                                                                                                                                                    | alignments                                                                                                                                    | new_translations                                                                                                                       | substitution_info                                                       | substituted_pairs        | substituted_words   | errors   | source_indices                                                                                                                                                                                                                                                                                                           |
# |---:|:------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------------------------------|:-------------------------------------------------------|:-------------------------------------------------------------------------------------------------------------------------------|:------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------|---------:|:-------------------------------------------------------------------------------------------------------------------------------------|:--------------------------------------------------------------------------------------------------------------------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:----------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------|:------------------------------------------------------------------------|:-------------------------|:--------------------|:---------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | 60 | /home/tajak/Parlamint-translation/Source-data/ParlaMint-CZ.conllu/ParlaMint-CZ.conllu/2013/ParlaMint-CZ_2013-12-10-ps2013-004-01-014-022.conllu | ParlaMint-CZ_2013-12-10-ps2013-004-01-014-022.conllu | ParlaMint-CZ_2013-12-10-ps2013-004-01-014-022.u3.p1.s2 | Nyní bych požádal pana poslance Jeronýma Tejce jako předsedu ústavněprávního výboru, aby nám navrhl zpravodaje pro prvé čtení. | Nyní bych požádal pana poslance Jeronýma Tejce jako předsedu ústavněprávního výboru , aby by nám navrhl zpravodaje pro prvé čtení . | {5: ['Jeronýma', 'Jeroným'], 6: ['Tejce', 'Tejc']}             |       18 | I would now ask Mr Jerome Tejc as President of the Constitutional Legal Committee to propose to us the rapporteur for first reading. | I would now ask Mr Jerome Tejc as President of the Constitutional Legal Committee to propose to us the rapporteur for first reading . | ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Last'] | {1: '2', 2: '2', 3: '1', 4: '3', 5: '5', 6: '6', 7: '7', 8: '8', 9: '9', 12: '10', 13: '10', 14: '11', 15: '13', 16: '16', 17: '14', 18: '15', 20: '17', 21: '18', 22: '19', 23: '20', 24: '21'} | {3: '1', 2: '2', 4: '3', 5: '4, 5', 6: '6', 7: '7', 8: '8', 9: '9', 12: '10', 14: '11', 15: '13', 17: '14', 18: '15', 16: '16', 20: '17', 21: '18', 22: '19', 23: '20', 24: '21'} | {0: 2, 1: 1, 2: 3, 3: 4, 4: 4, 5: 5, 6: 6, 7: 7, 8: 8, 9: 11, 10: 13, 12: 14, 13: 16, 14: 17, 15: 15, 16: 19, 17: 20, 18: 21, 19: 22, 20: 23} | I would now ask Mr Jeroným Tejc as President of the Constitutional Legal Committee to propose to us the rapporteur for first reading . | [('Jerome', 'Jeroným'), "No substitution: ('Tejc', 'Tejc')"]            | [('Jerome', 'Jeroným')]  | {6: 'Jerome'}       | No       | [['Nyní', 1], ['bych', 2], ['požádal', 3], ['pana', 4], ['poslance', 5], ['Jeronýma', 6], ['Tejce', 7], ['jako', 8], ['předsedu', 9], ['ústavněprávního', 10], ['výboru', 11], [',', 12], ['aby', 13], ['by', 14], ['nám', 15], ['navrhl', 16], ['zpravodaje', 17], ['pro', 18], ['prvé', 19], ['čtení', 20], ['.', 21]] |
# | 62 | /home/tajak/Parlamint-translation/Source-data/ParlaMint-CZ.conllu/ParlaMint-CZ.conllu/2013/ParlaMint-CZ_2013-12-10-ps2013-004-01-014-022.conllu | ParlaMint-CZ_2013-12-10-ps2013-004-01-014-022.conllu | ParlaMint-CZ_2013-12-10-ps2013-004-01-014-022.u4.p1.s1 | Vážený pane předsedající, vážené kolegyně a kolegové, dovoluji si navrhnout pana poslance Stanislava Grospiče.                 | Vážený pane předsedající , vážené kolegyně a kolegové , dovoluji si navrhnout pana poslance Stanislava Grospiče .                   | {14: ['Stanislava', 'Stanislav'], 15: ['Grospiče', 'Grospič']} |       14 | Mr President, ladies and gentlemen, I would like to propose Mr Stanislav Grospic.                                                    | Mr President , ladies and gentlemen , I would like to propose Mr Stanislav Grospic .                                                  | ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Last']                                                           | {1: '1', 2: '3', 3: '4', 4: '5', 5: '7', 6: '8', 7: '9', 8: '10', 9: '10', 10: '10', 11: '11', 12: '12', 13: '14', 14: '15', 15: '16', 16: '17'}                                                 | {1: '1, 2', 2: '3', 3: '4', 4: '5, 6', 5: '7', 6: '8', 7: '9', 10: '10', 11: '11', 12: '12', 13: '13, 14', 14: '15', 15: '16', 16: '17'}                                          | {0: 0, 1: 0, 2: 1, 3: 2, 4: 3, 5: 3, 6: 4, 7: 5, 8: 6, 9: 9, 10: 10, 11: 11, 12: 12, 13: 12, 14: 13, 15: 14, 16: 15}                          | Mr President , ladies and gentlemen , I would like to propose Mr Stanislav Grospič .                                                   | ["No substitution: ('Stanislav', 'Stanislav')", ('Grospic', 'Grospič')] | [('Grospic', 'Grospič')] | {15: 'Grospic'}     | No       | [['Vážený', 1], ['pane', 2], ['předsedající', 3], [',', 4], ['vážené', 5], ['kolegyně', 6], ['a', 7], ['kolegové', 8], [',', 9], ['dovoluji', 10], ['si', 11], ['navrhnout', 12], ['pana', 13], ['poslance', 14], ['Stanislava', 15], ['Grospiče', 16], ['.', 17]]                                                       |
