# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=6
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=6

# %%
import pandas as pd
import csv

# %%
# Define the lang code
lang_code = "UA"

# Define final path
final_path = "/home/tajak/Parlamint-translation/Note-translation/Final-data-CSV/ParlaMint-{}.notes.translated.ana.tsv".format(lang_code)

temp_path = "/home/tajak/Parlamint-translation/Note-translation/Final-data-CSV/before-sorting/ParlaMint-{}.notes.translated-before-sorting.ana.csv".format(lang_code)

# %%
# Open the dataframe
df = pd.read_csv(final_path, sep="\t")

df.head(2)
# Out:
# /tmp/ipykernel_2677210/651500763.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(final_path, sep="\t", error_bad_lines=False)
# Skipping line 622: expected 7 fields, saw 10
#    tag       type  content xml:lang  length     translation corpus
# 0  gap  inaudible  Не чути       uk     2.0         Unheard     UA
# 1  gap  inaudible  Не Чути       uk     2.0  Don't hear it.     UA

# %% [markdown]
# ## Analyse results

# %%
df.describe(include="all")
# Out:
#           tag   type      content xml:lang        length      translation  \
# count   61350  45564        61350    61350  61348.000000            61348
# unique      5     11        61281        3           NaN            54793
# top      note   time  ЛИТВИН В.М.       uk           NaN  ♪ I'll be right
# freq    59869  38257            3    60758           NaN              920
# mean      NaN    NaN          NaN      NaN      2.568348              NaN
# std       NaN    NaN          NaN      NaN      2.993362              NaN
# min       NaN    NaN          NaN      NaN      1.000000              NaN
# 25%       NaN    NaN          NaN      NaN      1.000000              NaN
# 50%       NaN    NaN          NaN      NaN      1.000000              NaN
# 75%       NaN    NaN          NaN      NaN      3.000000              NaN
# max       NaN    NaN          NaN      NaN     86.000000              NaN
#
#        corpus
# count   61348
# unique      1
# top        UA
# freq    61348
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN

# %%
# Print total no. of words
df.length.sum()
# Out:
# 221203

# %%
df.head(20)
# Out:
#          tag       type                                            content  \
# 0        gap  inaudible                                            Не чути
# 1        gap  inaudible                                            Не Чути
# 2        gap  inaudible                                            не чути
# 3        gap  inaudible                                           Не чути)
# 4        gap  inaudible                                           (Не чути
# 5        gap  inaudible                                            НЕ ЧУТИ
# 6        gap  inaudible                                       Нерозбірливо
# 7        gap  inaudible                                       нерозбірливо
# 8   incident     action                                   Хвилина мовчання
# 9   incident     action                       Лунає Державний Гімн України
# 10  incident     action                  Лунає Гімн Державний Гімн України
# 11  incident     action                                 Лунає Гімн України
# 12  incident     action                                  ХВИЛИНА МОВЧАННЯ.
# 13  incident     action                                 Лунає гімн України
# 14  incident     action           Депутати співають Державний Гімн України
# 15  incident     action             Лунає державний гімн Республіки Польща
# 16  incident     action                                   Хвилина Мовчання
# 17  incident     action                                 ЛУНАЄ ГІМН УКРАЇНИ
# 18  incident     action                                Лунає гімн України.
# 19  incident     action  У виконанні народних депутатів України лунає Д...
#
#    xml:lang  length                                        translation corpus
# 0        uk     2.0                                            Unheard     UA
# 1        uk     2.0                                     Don't hear it.     UA
# 2        uk     2.0                                        do not hear     UA
# 3        uk     2.0                                       Do not hear)     UA
# 4        uk     2.0                                  (Can't hear you.)     UA
# 5        uk     2.0                                        DO NOT HEAR     UA
# 6        uk     1.0                                       Inexplicable     UA
# 7        uk     1.0                                       inexplicable     UA
# 8        uk     2.0                                A Minute of Silence     UA
# 9        uk     4.0                       The National Hymn of Ukraine     UA
# 10       uk     5.0                     The Hymn State Hymn of Ukraine     UA
# 11       uk     3.0                    The Moon of the Hymn of Ukraine     UA
# 12       uk     2.0                             A MINUTE OF QUIETNESS.     UA
# 13       uk     3.0                              The Anthem of Ukraine     UA
# 14       uk     5.0          The MPs sing the National Hymn of Ukraine     UA
# 15       uk     5.0      The National Anthem of the Republic of Poland     UA
# 16       uk     2.0                                A Minute of Silence     UA
# 17       uk     3.0                                 THE FUN OF UKRAINE     UA
# 18       uk     3.0                      The anthem of Ukraine echoes.     UA
# 19       uk     9.0  The National Hymn of Ukraine is on the move in...     UA

# %% [markdown]
# ## Remove foreign language

# %%
# Inspect whether there is any additional language
print(df.shape)
print(df["xml:lang"].value_counts().to_markdown())
# Out:
# (61350, 7)
# |    |   xml:lang |
# |:---|-----------:|
# | uk |      60758 |
# | ru |        590 |
# | UA |          2 |

# %%
df[df["xml:lang"] == "en"]
# Out:
#    tag       type                                            content xml:lang  \
# 0  gap  editorial  Technical problem: content could not be proces...       en
#
#    length                                        translation corpus
# 0      11  Technical problem: content would not be proces...     FI

# %%
# Remove instances that are in non-target language
df = df[df["xml:lang"] == "fi"]

# Inspect the results
df.describe(include="all")
# Out:
#          tag             type  \
# count   8503             5087
# unique     2                1
# top     note  relatedDocument
# freq    5087             5087
# mean     NaN              NaN
# std      NaN              NaN
# min      NaN              NaN
# 25%      NaN              NaN
# 50%      NaN              NaN
# 75%      NaN              NaN
# max      NaN              NaN
#
#                                                   content xml:lang  \
# count                                                8503     8503
# unique                                               8503        1
# top     Hallituksen esitys eduskunnalle laeiksi euroop...       fi
# freq                                                    1     8503
# mean                                                  NaN      NaN
# std                                                   NaN      NaN
# min                                                   NaN      NaN
# 25%                                                   NaN      NaN
# 50%                                                   NaN      NaN
# 75%                                                   NaN      NaN
# max                                                   NaN      NaN
#
#              length                       translation corpus
# count   8503.000000                              8503   8503
# unique          NaN                              8485      1
# top             NaN  Government proposal HE 9/2015 vp     FI
# freq            NaN                                 3   8503
# mean       6.940492                               NaN    NaN
# std        4.366581                               NaN    NaN
# min        1.000000                               NaN    NaN
# 25%        5.000000                               NaN    NaN
# 50%        5.000000                               NaN    NaN
# 75%        7.000000                               NaN    NaN
# max       51.000000                               NaN    NaN

# %%
df.length.sum()
# Out:
# 59015

# %%
df.to_csv("{}".format(final_path), index=False, sep="\t", quoting=csv.QUOTE_NONE, quotechar="",  escapechar="\\")

# %% [markdown]
# After saving, inspect the saved file - check whether quotes are still present (that you did not delete them by saving the file too many times.)
