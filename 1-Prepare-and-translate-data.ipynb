# %% [markdown]
# ## Import the data

# %%
import pandas as pd
import regex as re
from bs4 import BeautifulSoup as bs
import os
import tqdm as tqdm

# %% [markdown]
# ### Option 1: Beautiful Soup (for TEI) - worse option if you need sentences

# %% [markdown]
# I helped myself with the tutorial at https://komax.github.io/blog/text/python/xml/parsing_tei_xml_python/

# %%
# Get a lis of TEI files

path = "ParlaMint-SI.TEI"
dir_list = os.listdir(path)

# Keep only files with parliamentary sessions:

parl_list = []

for i in dir_list:
	if "ParlaMint-SI_" in i:
		parl_list.append(i)

parl_list

# %% [markdown]
# The number of all files is 414 sessions.

# %%
with open(f"ParlaMint-SI.TEI.ana/ParlaMint-SI_2014-08-01-SDZ7-Redna-01.ana.xml", "r") as file:
	# Read each line in the file, readlines() returns a list of lines
	content = bs(file, 'lxml')

# %%
# Search for all segments
seg_list = content.find("seg")

# Find sentences and words using the findChildren method
sentences = seg_list.findChildren("s", recursive=False)
sentences

for i in sentences:
	print(i.getText())

# %%
# Read each XML file using the lxml parser.
# This parser transforms the XML document into a traversable tree, a beautiful soup stored in variable content.

# Create an empty df
df = pd.DataFrame({"session": [""], "xlmid": [""], "text": [""]})

for i in parl_list:
    with open(f"ParlaMint-SI.TEI.ana/{i}", "r") as file:
        # Read each line in the file, readlines() returns a list of lines
        content = bs(file, 'lxml')

        # Search for all segments
        seg_list = content.find_all("seg")

        # Get the session ID
        current_id = content.tei["xml:id"]

        current_df = pd.DataFrame({"xlmid": [x["xml:id"] for x in seg_list], "text": [x.getText() for x in seg_list]})
        current_df["session"] = current_id

        # Merge the df with the previous df
        df = pd.concat([df,current_df])

# %%
df.describe(include="all")

# %% [markdown]
# ### Option 2: From CONLLU with regex

# %%
# Get a list of TEI files

path = "ParlaMint-SI.conllu"
dir_list = os.listdir(path)

# Keep only files with parliamentary sessions:

parl_list = []

# Filter out only relevant files
for i in dir_list:
	if "ParlaMint-SI_" in i:
		if ".conllu" in i:
			parl_list.append(i)

len(parl_list)
# Out:
# 414

# %%
# Create an empty df
df = pd.DataFrame({"file": [""], "sentence_id": [""], "text": [""]})

# %%
# Create regexes
sen_re = re.compile("# sent_id = (.*?)\n")
text_re = re.compile("# text = (.*?)\n")

# %%
# Find all relevant information from the conllu files and save everything in a dataframe

for i in parl_list:

	file = open(f"ParlaMint-SI.conllu/{i}", "r").read()

	# Find sentence ids and texts
	sen_ids = sen_re.findall(file)
	texts = text_re.findall(file)
	
	new_df = pd.DataFrame({"sentence_id": sen_ids, "text": texts})
	new_df["file"] = i

	# Merge df to the previous df
	df = pd.concat([df, new_df])

df.head()
# Out:
#                                            file  \
# 0
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 2  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 3  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
#
#                                     sentence_id  \
# 0
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1.1
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg2.1
# 2  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3.1
# 3  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3.2
#
#                                                 text
# 0
# 0           Nadaljujemo s prekinjeno 17. sejo zbora.
# 1  Prehajamo na 2. TOČKO DNEVNEGA REDA, TO JE NA ...
# 2  Predlog zakona je v obravnavo zboru predložil ...
# 3  V zvezi s tem predlogom zakona Odbor za zdravs...

# %%
# Remove the first row
df = df.drop([0], axis="index")

# Reset index
df = df.reset_index(drop=True)

# Show the results
df.describe(include="all")
# Out:
#                                                 file  \
# count                                        1078584
# unique                                           414
# top     ParlaMint-SI_2016-11-23-SDZ7-Redna-24.conllu
# freq                                            6185
#
#                                          sentence_id         text
# count                                        1078584      1078584
# unique                                       1078584       918195
# top     ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg2.1  Hvala lepa.
# freq                                               1        27653

# %% [markdown]
# The Parlamint-SI consists of 414 files and 1,078,584 sentences.

# %%
# Add information on length
df["length"] = df["text"].str.split().str.len()

df.head(2)
# Out:
#                                            file  \
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
#
#                                     sentence_id  \
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg2.1
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3.1
#
#                                                 text  length
# 0  Prehajamo na 2. TOČKO DNEVNEGA REDA, TO JE NA ...      28
# 1  Predlog zakona je v obravnavo zboru predložil ...       9

# %%
# Add information on the segment id (which is also used in TEI files)
seg_re = re.compile("(.*?)\.\d+")

df["seg_id"] = [seg_re.findall(x)[0] for x in df.sentence_id]

df.head(2)
# Out:
#                                            file  \
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
#
#                                     sentence_id  \
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg2.1
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3.1
#
#                                                 text  length  \
# 0  Prehajamo na 2. TOČKO DNEVNEGA REDA, TO JE NA ...      28
# 1  Predlog zakona je v obravnavo zboru predložil ...       9
#
#                                        seg_id
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg2
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3

# %%
df.tail()
# Out:
#                                                  file  \
# 1078579  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.conllu
# 1078580  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.conllu
# 1078581  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.conllu
# 1078582  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.conllu
# 1078583  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.conllu
#
#                                             sentence_id  \
# 1078579  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.seg835.1
# 1078580  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.seg835.2
# 1078581  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.seg837.1
# 1078582  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.seg837.2
# 1078583  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.seg838.1
#
#                                                       text  length  \
# 1078579                                         Glasujemo.       1
# 1078580  Navzočih je 59 poslank in poslancev, za je gla...      13
# 1078581                   Ugotavljam, da je zakon sprejet.       5
# 1078582          S tem zaključujem to točko dnevnega reda.       7
# 1078583  Prekinjam 36. sejo Državnega zbora, ki jo bomo...      13
#
#                                                seg_id
# 1078579  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.seg835
# 1078580  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.seg835
# 1078581  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.seg837
# 1078582  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.seg837
# 1078583  ParlaMint-SI_2017-12-14-SDZ7-Redna-36.seg838

# %%
# Save the dataframe
df.to_csv("Parlamint-SI-sentences.csv", sep="\t")

# %% [markdown]
# ## Machine translate a sample

# %%
# Open the file, created in the previous step
df = pd.read_csv("Parlamint-SI-sentences.csv", sep="\t", index_col=0)

df.head()
# Out:
# /home/tajak/anaconda3/lib/python3.9/site-packages/numpy/lib/arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                                            file  \
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 2  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 3  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 4  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
#
#                                     sentence_id  \
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg2.1
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3.1
# 2  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3.2
# 3  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg4.1
# 4  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg5.1
#
#                                                 text  length  \
# 0  Prehajamo na 2. TOČKO DNEVNEGA REDA, TO JE NA ...      28
# 1  Predlog zakona je v obravnavo zboru predložil ...       9
# 2  V zvezi s tem predlogom zakona Odbor za zdravs...      22
# 3  Besedo dajem predsednici odbora Anji Bah Žiber...      12
# 4                          Hvala lepa, predsedujoči.       3
#
#                                        seg_id
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg2
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3
# 2  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3
# 3  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg4
# 4  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg5

# %%
df.describe(include="all")
# Out:
#                                                 file  \
# count                                        1078584
# unique                                           414
# top     ParlaMint-SI_2016-11-23-SDZ7-Redna-24.conllu
# freq                                            6185
# mean                                             NaN
# std                                              NaN
# min                                              NaN
# 25%                                              NaN
# 50%                                              NaN
# 75%                                              NaN
# max                                              NaN
#
#                                          sentence_id         text  \
# count                                        1078584      1078584
# unique                                       1078584       918195
# top     ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg2.1  Hvala lepa.
# freq                                               1        27653
# mean                                             NaN          NaN
# std                                              NaN          NaN
# min                                              NaN          NaN
# 25%                                              NaN          NaN
# 50%                                              NaN          NaN
# 75%                                              NaN          NaN
# max                                              NaN          NaN
#
#               length                                       seg_id
# count   1.078584e+06                                      1078584
# unique           NaN                                       280629
# top              NaN  ParlaMint-SI_2014-11-20-SDZ7-Redna-02.seg69
# freq             NaN                                          147
# mean    1.875484e+01                                          NaN
# std     1.489782e+01                                          NaN
# min     1.000000e+00                                          NaN
# 25%     7.000000e+00                                          NaN
# 50%     1.600000e+01                                          NaN
# 75%     2.600000e+01                                          NaN
# max     4.700000e+02                                          NaN

# %%
sample_files = list(df["file"].unique())[:3]
sample_files
# Out:
# ['ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu',
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.conllu',
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.conllu']

# %%
# Take the first 3 files for a sample

df_sample = df[df.file.isin(sample_files)]
df_sample.describe(include="all")
# Out:
#                                                 file  \
# count                                           8217
# unique                                             3
# top     ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# freq                                            3486
# mean                                             NaN
# std                                              NaN
# min                                              NaN
# 25%                                              NaN
# 50%                                              NaN
# 75%                                              NaN
# max                                              NaN
#
#                                          sentence_id         text  \
# count                                           8217         8217
# unique                                          8217         7386
# top     ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg2.1  Hvala lepa.
# freq                                               1          211
# mean                                             NaN          NaN
# std                                              NaN          NaN
# min                                              NaN          NaN
# 25%                                              NaN          NaN
# 50%                                              NaN          NaN
# 75%                                              NaN          NaN
# max                                              NaN          NaN
#
#              length                                        seg_id
# count   8217.000000                                          8217
# unique          NaN                                          2055
# top             NaN  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408
# freq            NaN                                            95
# mean      18.557990                                           NaN
# std       14.180222                                           NaN
# min        1.000000                                           NaN
# 25%        8.000000                                           NaN
# 50%       16.000000                                           NaN
# 75%       26.000000                                           NaN
# max      143.000000                                           NaN

# %% [markdown]
# The sample file has 8217 sentences.

# %% [markdown]
# ### Find proper names in the sample

# %%
# Use the TEI files instead of conllu
sample_files_TEI = [x.replace("conllu", "ana.xml") for x in sample_files]
sample_files_TEI
# Out:
# ['ParlaMint-SI_2020-05-27-SDZ8-Redna-17.ana.xml',
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.ana.xml',
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.ana.xml']

# %%
# Create a regex to separate word id into segment id and word index
word_seg_re = re.compile("(.*)\.(\d+)")

# %%
# Find names from the TEI file with beautiful soup
names_list = []

for i in sample_files_TEI:

	# Open the file
	file = open(f"ParlaMint-SI.TEI.ana/{i}", "r")
	content = bs(file, 'lxml')

	# Search for all sentences
	seg_list = content.find_all("s")

	# Create a list of dictionaries for each sentence

	for i in content.find_all("s"):
		result = i.findChildren("name", type = "PER", recursive=False)
		if len(result) > 0:
			result_list = []
			for i in result:
				words = i.findChildren("w", recursive = False)
				for word in words:
					current_name = word.getText()
					current_lemma = word["lemma"]
					current_word_id = word["xml:id"]
					current_seg_id = word_seg_re.findall(current_word_id)
					word_list = [current_word_id, current_name, current_lemma]
					word_list.extend(current_seg_id)
					result_list.append(word_list)
			names_list.append(result_list)

len(names_list)
# Out:
# 816

# %%
names_list[:3]
# Out:
# [['ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg4.1.5',
#   'Anji',
#   'Anja',
#   ('ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg4.1', '5')],
#  ['ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg4.1.6',
#   'Bah',
#   'Bah',
#   ('ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg4.1', '6')],
#  ['ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg4.1.7',
#   'Žibert',
#   'Žibert',
#   ('ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg4.1', '7')]]

# %%
# Create a dictionary of sentences out of the names list
sent_dict = {}

for sentence in names_list:
	info_dic = {}
	for word in sentence:
		current_sent_id = word[3][0]
		# I'll substract one from the word index, because indexing in the TEI file starts with 1, not 0
		current_word_index = int(word[3][1]) - 1
		info_dic[current_word_index] = (word[1], word[2])
	sent_dict[current_sent_id] = info_dic

sent_dict
# Out:
# {'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg4.1': {4: ('Anji', 'Anja'),
#   5: ('Bah', 'Bah'),
#   6: ('Žibert', 'Žibert')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg8.1': {6: ('Marjan', 'Marjan'),
#   7: ('Maučec', 'Maučec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg9.1': {7: ('Tomaž', 'Tomaž'),
#   8: ('Gantar', 'Gantar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg11.1': {2: ('Marjanu', 'Marjan'),
#   3: ('Maučecu', 'Maučec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg13.1': {29: ('Franca', 'Franc'),
#   30: ('Kanglerja', 'Kangler')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg16.1': {13: ('Tini', 'Tina'),
#   14: ('Bregant', 'Bregant')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg21.2': {9: ('Monika', 'Monika'),
#   10: ('Gregorčič', 'Gregorčič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg23.2': {21: ('Krisa', 'Kris')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg28.1': {7: ('Željko', 'Željko'),
#   8: ('Cigler', 'Cigler')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg33.1': {10: ('Iva', 'Iva'),
#   11: ('Dimic.', 'dimic.')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg40.1': {5: ('Alenke', 'Alenka'),
#   6: ('Bratušek', 'Bratušek'),
#   9: ('Vojko', 'Vojko'),
#   10: ('Starović', 'Starović')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg42.5': {32: ('Slovenci',
#    'Slovenec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg42.6': {8: ('Krisa', 'Kris')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg45.1': {10: ('Branko', 'Branko'),
#   11: ('Simonovič', 'Simonovič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg50.1': {9: ('Jani', 'Jani'),
#   10: ('Ivanuša', 'Ivanuša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg54.1': {9: ('Nada', 'Nada'),
#   10: ('Brinovšek', 'Brinovšek')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg58.1': {5: ('Marjana', 'Marjan'),
#   6: ('Šarca', 'Šarec'),
#   9: ('Jože', 'Jože'),
#   10: ('Lenart', 'Lenart')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg62.1': {2: ('Marjana', 'Marjan'),
#   3: ('Šarca', 'Šarec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg63.1': {8: ('Franc', 'Franc'),
#   9: ('Trček', 'Trček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg74.1': {9: ('Bojanu', 'Bojan'),
#   10: ('Režunu', 'Režun')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg78.2': {8: ('Anji', 'Anja'),
#   9: ('Bah', 'Bah'),
#   10: ('Žibert', 'Žibert')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg82.1': {9: ('Bojan', 'Bojan'),
#   10: ('Režun', 'Režun'),
#   29: ('Alma', 'Alma'),
#   30: ('Mater', 'Mater')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg83.1': {7: ('Tomaž', 'Tomaž'),
#   8: ('Gantar', 'Gantar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg90.1': {5: ('Tini', 'Tina'),
#   6: ('Bregant', 'Bregant')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg95.2': {7: ('Željko', 'Željko'),
#   8: ('Cigler', 'Cigler')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg98.5': {40: ('Samo', 'Samo'),
#   41: ('Fakin', 'Fakin'),
#   43: ('Aleš', 'Aleš'),
#   44: ('Šabeder', 'Šabeder')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg101.1': {11: ('Iva', 'Iva'),
#   12: ('Dimic.', 'dimic.')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg107.1': {10: ('Branko', 'Branko'),
#   11: ('Simonovič', 'Simonovič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg109.1': {28: ('Alma', 'Alma'),
#   29: ('Mater', 'Mater'),
#   30: ('Europaea', 'Europaea')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg110.5': {11: ('Tomaža', 'Tomaž'),
#   12: ('Gantarja', 'Gantar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg114.1': {9: ('Jani', 'Jani'),
#   10: ('Ivanúša', 'Ivanúša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg115.2': {3: ('Ivánuša', 'Ivánuša'),
#   5: ('Ivanúša', 'Ivanúša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg119.2': {14: ('Alma', 'Alma'),
#   15: ('Mater', 'Mater'),
#   16: ('Europaea', 'Europaea')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg122.1': {10: ('Felice', 'Felice'),
#   11: ('Žiža', 'Žiža')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg124.5': {1: ('Hölgyeim',
#    'Hölgyeim'),
#   2: ('és', 'és'),
#   3: ('Uraim', 'Uraim')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg126.2': {16: ('Tomažu', 'Tomaž'),
#   17: ('Gantarju', 'Gantar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg130.1': {8: ('Nada', 'Nada'),
#   9: ('Brinovšek', 'Brinovšek')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg138.1': {4: ('Marjana', 'Marjan'),
#   5: ('Šarca', 'Šarec'),
#   8: ('Nik', 'Nik'),
#   9: ('Prebil', 'prebiti')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg143.1': {2: ('Marjana', 'Marjan'),
#   3: ('Šarca', 'Šarec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg146.1': {8: ('Bojana', 'Bojana'),
#   9: ('Muršič', 'Muršič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg154.1': {9: ('Branislav',
#    'Branislav'),
#   10: ('Rajić', 'Rajić')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg168.1': {10: ('Marjana', 'Marjan'),
#   11: ('Dolinšku', 'Dolinšek')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg171.1': {17: ('Slovencev',
#    'Slovenec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg175.2': {7: ('Ivi', 'Iva'),
#   8: ('Dimic.', 'dimic.')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg181.1': {14: ('Marjan', 'Marjan'),
#   15: ('Dolinšek', 'Dolinšek'),
#   22: ('Blaž', 'Blaž'),
#   23: ('Perko', 'Perko')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg188.2': {10: ('Iva', 'Iva'),
#   11: ('Dimic.', 'dimic.')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg191.1': {10: ('Marjana', 'Marjan'),
#   11: ('Šarca', 'Šarec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg195.1': {9: ('Ivan', 'Ivan'),
#   10: ('Hršak', 'Hršak')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg201.1': {8: ('Dušan', 'Dušan'),
#   9: ('Šiško', 'Šiško')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg210.1': {8: ('Tomaž', 'Tomaž'),
#   9: ('Lisec', 'Lisec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg218.1': {4: ('Marjana', 'Marjan'),
#   5: ('Šarca', 'Šarec'),
#   8: ('Lidija', 'Lidija'),
#   9: ('Divjak', 'Divjak'),
#   10: ('Mirnik', 'Mirnik')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg223.3': {24: ('Liste', 'lista'),
#   25: ('Marjana', 'Marjan'),
#   26: ('Šarca', 'Šarec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg226.1': {8: ('Bojana', 'Bojana'),
#   9: ('Muršič', 'Muršič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg232.1': {9: ('Branislav',
#    'Branislav'),
#   10: ('Rajić', 'Rajić')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg245.1': {15: ('Luko', 'Luka'),
#   16: ('Mescem', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg246.1': {15: ('Matejem', 'Matej'),
#   16: ('Tašner', 'Tašner'),
#   17: ('Vatovcem', 'Vatovec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg247.1': {9: ('Luki', 'Luka'),
#   10: ('Mescu', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg256.1': {8: ('Simonu', 'Simon'),
#   9: ('Zajcu', 'Zajc')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg266.2': {5: ('Alenke', 'Alenka'),
#   6: ('Bratušek', 'Bratušek'),
#   8: ('Marko', 'Marko'),
#   9: ('Bandelli', 'Bandelli')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg275.1': {9: ('Robert', 'Robert'),
#   10: ('Polnar', 'Polnar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg282.3': {6: ('Mesec', 'mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg284.1': {8: ('Jani', 'Jani'),
#   9: ('Ivanuša', 'Ivanuša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg290.1': {8: ('Janez', 'Janez'),
#   9: ('Moškrič', 'Moškrič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg297.1': {6: ('Robert', 'Robert'),
#   7: ('Pavšič', 'Pavšič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg300.1': {2: ('Marjana', 'Marjan'),
#   3: ('Šarca', 'Šarec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg303.1': {8: ('Meira', 'Meira'),
#   9: ('Hot', 'Hot')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg311.1': {8: ('Janja', 'Janja'),
#   9: ('Sluga', 'Sluga')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg324.1': {6: ('Željko', 'Željko'),
#   7: ('Cigler', 'Cigler')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg328.3': {1: ('Levici', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg328.7': {1: ('Levici', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg335.1': {10: ('Mihael', 'Mihael'),
#   11: ('Prevc', 'Prevc')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg346.1': {6: ('Luki', 'Luka'),
#   7: ('Mescu', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg349.7': {13: ('Violeta', 'Violeta'),
#   14: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg349.9': {0: ('Janša', 'Janša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg353.2': {4: ('Luka', 'Luka'),
#   5: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg354.1': {3: ('Mesec', 'mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg357.2': {16: ('Polnar', 'Polnar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg362.5': {19: ('Ekonomsko-socialni',
#    'ekonomskoniacialen')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg365.1': {8: ('Zajc', 'Zajc')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg373.1': {6: ('Edvard', 'Edvard'),
#   7: ('Paulič', 'Paulič'),
#   13: ('Iva', 'Iva'),
#   14: ('Dimic.', 'dimic.')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg381.1': {4: ('Iva', 'Iva'),
#   5: ('Dimic', 'Dimic'),
#   10: ('Rudi', 'Rudi'),
#   11: ('Medved', 'Medved')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg384.2': {18: ('Levica', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg389.1': {4: ('Rudi', 'Rudi'),
#   5: ('Medved', 'Medved'),
#   10: ('Franc', 'Franc'),
#   11: ('Trček', 'Trček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg397.1': {5: ('Franc', 'Franc'),
#   6: ('Trček', 'Trček'),
#   11: ('Branislav', 'Branislav'),
#   12: ('Rajić', 'Rajić')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg400.2': {4: ('Doblekar',
#    'Doblekar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg404.4': {5: ('MGRT-ja', 'MGRT')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg405.2': {3: ('Engelsa', 'Engels'),
#   25: ('Dickensa', 'Dickens')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg405.5': {60: ('Pelinkovec',
#    'Pelinkovec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg405.11': {1: ('Zajc', 'Zajc'),
#   3: ('Zeko', 'Zeko')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg405.15': {2: ('Ikeo', 'Ikea')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg406.6': {33: ('Meira', 'Meira')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.4': {7: ('Ivi', 'Ivi')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.7': {19: ('Novaku', 'Novak')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.11': {11: ('Janezu', 'Janez'),
#   12: ('Janši', 'Janša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.12': {18: ('Soni', 'Soni')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.17': {2: ('Miha', 'Miha')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.18': {4: ('Zofka', 'Zofka')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.19': {5: ('Zofko', 'Zofka')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.21': {11: ('Jani', 'Jani')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.26': {1: ('Prevc', 'Prevc')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.30': {14: ('Modrijane',
#    'Modrijan')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.31': {5: ('Modrijane',
#    'Modrijana'),
#   11: ('Modrijanom', 'Modrijan')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.32': {4: ('Modrijani',
#    'Modrijan'),
#   8: ('Tanja', 'Tanja'),
#   9: ('Žagar', 'Žagar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.35': {2: ('Kajo', 'Kaja'),
#   3: ('Draksler', 'Draksler')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.45': {2: ('Zajc', 'Zajc')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.49': {9: ('Tanji', 'Tanja'),
#   10: ('Reiner', 'Reiner')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.50': {5: ('Levice', 'Levica'),
#   10: ('Grims', 'Grims')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.54': {19: ('Slovenci',
#    'Slovenec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.58': {23: ('Joško', 'Joško')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.89': {9: ('Kosa', 'Kos')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408.95': {5: ('Levici', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg409.9': {39: ('Rajić', 'Rajić')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg409.12': {44: ('Franček',
#    'Franček'),
#   45: ('Drenovec', 'Drenovec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg412.6': {69: ('Čeferina',
#    'Čeferin'),
#   78: ('Čeferin', 'Čeferin')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg412.26': {6: ('Trček', 'Trček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg414.1': {4: ('Trček', 'Trček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg415.1': {5: ('Branislav',
#    'Branislav'),
#   6: ('Rajić', 'Rajić'),
#   11: ('Jani', 'Jani'),
#   12: ('Möderndorfer', 'Möderndorfer')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg418.8': {21: ('Levica', 'levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg418.15': {11: ('Luka', 'Luka')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg421.1': {4: ('Jani', 'Jani'),
#   5: ('Möderndorfer', 'Möderndorfer'),
#   10: ('Blaž', 'Blaž'),
#   11: ('Pavlin', 'Pavlin')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg424.3': {9: ('Čuš', 'Čuš')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg425.4': {14: ('Levica', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg428.5': {11: ('Luka', 'Luka'),
#   12: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg430.23': {2: ('Slovenca',
#    'Slovenec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg430.25': {6: ('Trčkom', 'Trček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg436.1': {1: ('Möderndorfer',
#    'Möderndorfer')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg436.8': {7: ('Petra', 'Peter')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg440.1': {3: ('Möderndorfer',
#    'Möderndorfer')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg442.4': {16: ('Luka', 'Luka')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg442.6': {6: ('Luka', 'Luka')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg446.1': {0: ('Jani', 'Jani')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg448.2': {1: ('Blaž', 'Blaž'),
#   2: ('Pavlin', 'Pavlin'),
#   10: ('Igor', 'Igor'),
#   11: ('Peček', 'Peček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg456.1': {4: ('Igor', 'Igor'),
#   5: ('Peček', 'Peček'),
#   10: ('Monika', 'Monika'),
#   11: ('Gregorčič', 'Gregorčič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg459.12': {2: ('Trček', 'Trček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg461.2': {1: ('Monika', 'Monika'),
#   2: ('Gregorčič', 'Gregorčič'),
#   9: ('Violeta', 'Violeta'),
#   10: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg470.1': {1: ('Luka', 'Luka'),
#   2: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg476.1': {3: ('Gregorčič',
#    'Gregorčič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg480.2': {1: ('Violeta', 'Violeta'),
#   2: ('Tomić', 'Tomić'),
#   9: ('Franc', 'Franc'),
#   10: ('Jurša', 'Jurša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg486.6': {6: ('Cityparkom',
#    'Citypark')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg490.1': {1: ('Monika', 'Monika'),
#   2: ('Gregorčič', 'Gregorčič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg496.1': {1: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg496.5': {7: ('Simon', 'Simon'),
#   8: ('Zajc', 'Zajc')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg503.1': {3: ('Luka', 'Luka'),
#   4: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg508.14': {11: ('Monike', 'Monika'),
#   12: ('Gregorčič', 'Gregorčič'),
#   24: ('Ladija', 'Ladi'),
#   25: ('Rožiča', 'Rožič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg511.1': {2: ('Mateja', 'Mateja'),
#   3: ('Udovč', 'Udovč'),
#   10: ('Boštjan', 'Boštjan'),
#   11: ('Koražija', 'Koražija')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg515.11': {5: ('Slovencev',
#    'Slovenec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg515.22': {27: ('Božička',
#    'Božiček'),
#   30: ('Mraza', 'Mraz'),
#   32: ('Miklavža', 'Miklavž')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg517.1': {3: ('Boštjan', 'Boštjan'),
#   4: ('Koražija', 'Koražija'),
#   10: ('Andrej', 'Andrej'),
#   11: ('Černigoj', 'Černigoj')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg519.11': {7: ('Luka', 'Luka')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg521.1': {3: ('Andrej', 'Andrej'),
#   4: ('Černigoj', 'Černigoj'),
#   10: ('Franc', 'Franc'),
#   11: ('Breznik', 'Breznik')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg525.1': {32: ('Ivo', 'Ivo'),
#   33: ('Dimic', 'Dimic')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg528.1': {3: ('Franc', 'Franc'),
#   4: ('Breznik', 'Breznik')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg528.3': {3: ('Bojana', 'Bojana'),
#   4: ('Muršič', 'Muršič'),
#   12: ('Franc', 'Franc'),
#   13: ('Kramar', 'Kramar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg532.47': {50: ('Violeta',
#    'Violeta')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg534.1': {4: ('Francu', 'Franc'),
#   5: ('Kramarju', 'Kramar'),
#   17: ('Željko', 'Željko'),
#   18: ('Cigler', 'Cigler'),
#   20: ('Danijel', 'Danijel'),
#   21: ('Krivec', 'Krivec'),
#   23: ('Jožef', 'Jožef'),
#   24: ('Horvat', 'Horvat'),
#   26: ('Luka', 'Luka'),
#   27: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg535.1': {1: ('Kramar', 'Kramar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg541.1': {3: ('Željko', 'Željko'),
#   4: ('Cigler', 'Cigler'),
#   10: ('Danijel', 'Danijel'),
#   11: ('Krivec', 'Krivec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg544.2': {7: ('Muršičeva',
#    'Muršičev')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg544.3': {6: ('Franjo', 'Franjo'),
#   7: ('Trček', 'Trček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg544.9': {4: ('Luka', 'Luka'),
#   5: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg545.4': {28: ('Levica', 'levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg546.1': {21: ('Levice', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg546.3': {5: ('Luka', 'Luka')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg546.10': {7: ('Mariča', 'Mariča'),
#   8: ('Lah', 'Lah')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg546.12': {7: ('Janijem', 'Jani'),
#   8: ('Möderndorferjem', 'Möderndorfer')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg549.1': {3: ('Jožef', 'Jožef'),
#   4: ('Horvat', 'Horvat'),
#   10: ('Luka', 'Luka'),
#   11: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg552.3': {11: ('Ludwig', 'Ludwig'),
#   12: ('Erhard', 'Erhard'),
#   14: ('Walter', 'Walter'),
#   15: ('Eucken', 'Eucken')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg552.4': {19: ('Levice', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg552.6': {5: ('Erhard', 'Erhard')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg553.2': {13: ('Levica', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg554.6': {13: ('Jani', 'Jani')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg559.1': {6: ('Luka', 'Luka'),
#   7: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg567.1': {6: ('Simon', 'Simon'),
#   7: ('Zajc', 'Zajc')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg574.1': {5: ('Luka', 'Luka'),
#   6: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg581.2': {6: ('Luka', 'Luka'),
#   7: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg582.3': {4: ('Marijan', 'Marijan'),
#   5: ('Pojbič', 'Pojbič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg587.2': {20: ('Levice', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg587.6': {3: ('Levica', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg588.1': {7: ('Muršič', 'Muršič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg588.7': {26: ('Levica', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg588.12': {9: ('Levica', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg588.13': {0: ('Miha', 'Miha'),
#   1: ('Kordiš', 'Kordiš'),
#   9: ('Siter', 'Siter')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg594.1': {3: ('Jože', 'Jože'),
#   4: ('Lenart', 'Lenart')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg602.1': {3: ('Predrag', 'Predrag'),
#   4: ('Baković', 'Baković')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg605.1': {16: ('Pojbiču', 'Pojbič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg607.3': {13: ('Mesec', 'mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg608.1': {9: ('Levica', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg610.1': {3: ('Mojca', 'Mojca'),
#   4: ('Škrinjar', 'Škrinjar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg617.1': {3: ('Jožef', 'Jožef'),
#   4: ('Horvat', 'Horvat')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg622.1': {3: ('Boris', 'Boris'),
#   4: ('Doblekar', 'Doblekar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg626.1': {6: ('Levice', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg626.3': {5: ('Levici', 'Levica'),
#   16: ('Marijan', 'Marijan'),
#   17: ('Pojbič', 'Pojbič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg626.4': {7: ('Levice', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg626.6': {1: ('Levica', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg627.2': {11: ('Levica', 'levica'),
#   34: ('Levica', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg627.4': {2: ('Muršič', 'Muršič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg627.5': {2: ('Levica', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg628.1': {5: ('Levica', 'Levica'),
#   27: ('Janez', 'Janez'),
#   28: ('Janša', 'Janša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg629.1': {29: ('Janša', 'Janša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg630.4': {29: ('Levice', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg631.2': {23: ('Levice', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg633.1': {6: ('Luka', 'Luka'),
#   7: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg669.1': {1: ('Luka', 'Luka'),
#   2: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg671.1': {1: ('Levici', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg699.1': {1: ('Nataša', 'Nataša'),
#   2: ('Sukič', 'Sukič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg721.1': {1: ('Nataša', 'Nataša'),
#   2: ('Sukič', 'Sukič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg726.1': {1: ('Rudi', 'Rudi'),
#   2: ('Medved', 'Medved')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg728.1': {4: ('Marjana', 'Marjan'),
#   5: ('Šarca', 'Šarec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg731.1': {1: ('Primož', 'Primož'),
#   2: ('Siter', 'Siter')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg733.7': {18: ('Srebrna', 'srebrn')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg735.1': {1: ('Trček', 'Trček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg738.1': {1: ('Robert', 'Robert'),
#   2: ('Pavšič', 'Pavšič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg741.1': {1: ('Nataša', 'Nataša'),
#   2: ('Sukič', 'Sukič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg743.2': {8: ('Vizjaka', 'Vizjak')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg744.1': {1: ('Violeta', 'Violeta'),
#   2: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg746.5': {1: ('Vizjak', 'Vizjak')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg746.6': {15: ('Vizjak', 'Vizjak')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg746.9': {5: ('Mesec', 'mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg747.1': {1: ('Željko', 'Željko'),
#   2: ('Cigler', 'Cigler')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg750.1': {1: ('Miha', 'Miha'),
#   2: ('Kordiš', 'Kordiš')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg752.2': {29: ('Počivalšek',
#    'Počivalšek')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg752.3': {8: ('Janeza', 'Janez'),
#   9: ('Janše', 'Janša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg759.1': {4: ('Borut', 'Borut'),
#   5: ('Pahor', 'Pahor'),
#   37: ('Nino', 'Nina'),
#   38: ('Savin', 'Savin'),
#   39: ('Bossiere', 'Bossiere'),
#   42: ('Jureta', 'Jure'),
#   43: ('Vidmarja', 'Vidmar'),
#   61: ('Klemna', 'Klemen'),
#   62: ('Podobnika', 'Podobnik')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg761.1': {13: ('Nataši', 'Nataša'),
#   14: ('Kovač', 'Kovač')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg764.1': {1: ('Nina', 'Nina'),
#   2: ('Savin', 'Savin'),
#   3: ('Bossiere', 'Bossiere')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg764.9': {7: ('Nina', 'Nina'),
#   8: ('Savin', 'Savin'),
#   9: ('Bossiere', 'Bossiere')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg765.1': {2: ('Jure', 'Jure'),
#   3: ('Vidmar', 'Vidmar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg765.3': {1: ('Vidmarja', 'Vidmar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg765.7': {1: ('Vidmar', 'Vidmar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg765.10': {1: ('Jure', 'Jure'),
#   2: ('Vidmar', 'Vidmar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg765.11': {7: ('Jure', 'Jure'),
#   8: ('Vidmar', 'Vidmar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg768.4': {23: ('Klemena', 'Klemen'),
#   24: ('Podobnika', 'Podobnik')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg768.5': {1: ('Podobnik',
#    'Podobnik')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg768.10': {1: ('Podobnik',
#    'Podobnik')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg768.15': {12: ('Klemen', 'Klemen'),
#   13: ('Podobnik', 'Podobnik')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg769.1': {8: ('Klemena', 'Klemen'),
#   9: ('Podobnika', 'Podobnik')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg772.5': {2: ('Franc', 'Franc'),
#   3: ('Breznik', 'Breznik'),
#   9: ('Andreja', 'Andreja'),
#   10: ('Zabret', 'Zabret'),
#   16: ('Boštjan', 'Boštjan'),
#   17: ('Koražija', 'Koražija'),
#   23: ('Blaž', 'Blaž'),
#   24: ('Pavlin', 'Pavlin')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg772.7': {9: ('Jerneja', 'Jernej'),
#   10: ('Bergoč', 'Bergoč')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg784.1': {8: ('Klemna', 'Klemen'),
#   9: ('Podobnika', 'Podobnik')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg784.4': {6: ('Klemen', 'Klemen'),
#   7: ('Podobnik', 'Podobnik')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg784.5': {1: ('Klemnu', 'Klemen'),
#   2: ('Podobniku', 'Podobnik')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg785.3': {7: ('Nina', 'Nina'),
#   8: ('Savin', 'Savin'),
#   9: ('Bossiere', 'Bossiere'),
#   13: ('Jure', 'Jure'),
#   14: ('Vidmar', 'Vidmar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg785.6': {17: ('Juretu', 'Jure'),
#   18: ('Vidmarju', 'Vidmar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg791.1': {9: ('Jureta', 'Jure'),
#   10: ('Vidmarja', 'Vidmar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg791.5': {1: ('Jure', 'Jure'),
#   2: ('Vidmar', 'Vidmar')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg795.1': {23: ('Romana', 'Romana'),
#   24: ('Jordan', 'Jordan'),
#   30: ('Borut', 'Borut'),
#   31: ('Bratina', 'Bratina'),
#   33: ('Aleš', 'Aleš'),
#   34: ('Ferlež', 'Ferlež')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg800.1': {10: ('Maruše', 'Maruša'),
#   11: ('Bartol', 'Bartol')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg803.1': {25: ('Maruša', 'Maruša'),
#   26: ('Bartol', 'Bartol')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg808.1': {10: ('Monike', 'Monika'),
#   11: ('Mihelčič', 'Mihelčič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg811.1': {25: ('Monika', 'Monika'),
#   26: ('Mihelčič', 'Mihelčič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg818.1': {31: ('Jožef', 'Jožef'),
#   32: ('Kocuvan', 'Kocuvan')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg832.1': {6: ('Marjana', 'Marjan'),
#   7: ('Šarca', 'Šarec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg833.1': {1: ('Brane', 'Brane'),
#   2: ('Golubović', 'Golubović')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg835.9': {3: ('Janeza', 'Janez'),
#   4: ('Janše', 'Janša'),
#   6: ('Zdravka', 'Zdravko'),
#   7: ('Počivalška', 'Počivalšek'),
#   9: ('Mateja', 'Matej'),
#   10: ('Tonina', 'Tonin'),
#   12: ('Aleksandre', 'Aleksandra'),
#   13: ('Pivec', 'Pivec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg837.1': {1: ('Janja', 'Janja'),
#   2: ('Sluga', 'Sluga')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg842.1': {2: ('Matej', 'Matej'),
#   3: ('T.', 't.'),
#   4: ('Vatovec', 'Vatovec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg844.5': {1: ('Janez', 'Janez'),
#   2: ('Janša', 'Janša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg849.1': {1: ('Möderndorfer',
#    'Möderndorfer')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg853.1': {1: ('Luka', 'Luka'),
#   2: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg855.15': {9: ('Alenka', 'Alenka'),
#   10: ('Jeraj', 'Jeraj'),
#   12: ('Twitterju', 'Twitter')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg856.5': {3: ('Gregorja', 'Gregor'),
#   4: ('Periča', 'Perič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg858.1': {1: ('Matjaž', 'Matjaž'),
#   2: ('Han', 'Han')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg860.9': {2: ('LMŠ', 'LMŠ'),
#   25: ('Möderndorferju', 'Möderndorfer')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg860.13': {4: ('Periča', 'Perič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg860.15': {14: ('Peričem', 'Perič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg860.27': {7: ('Perič', 'Perič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg861.1': {1: ('Krivec', 'Krivec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg863.6': {10: ('Matjaž', 'Matjaž')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg863.17': {5: ('Hanžka', 'Hanžek')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg864.1': {3: ('Perič', 'Perič'),
#   9: ('Möderndorfer', 'Möderndorfer')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg865.1': {3: ('Han', 'Han')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg866.1': {23: ('Krivec', 'Krivec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg867.1': {3: ('Luka', 'Luka'),
#   4: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg869.1': {9: ('Matjaž', 'Matjaž'),
#   10: ('Han', 'Han')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg869.4': {13: ('Danijel', 'Danijel'),
#   14: ('Krivec', 'Krivec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg870.3': {2: ('Levica', 'levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg873.1': {1: ('Janja', 'Janja'),
#   2: ('Sluga', 'Sluga')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg876.16': {1: ('Perič', 'Perič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg877.1': {1: ('Jože', 'Jože'),
#   2: ('Horvat', 'Horvat')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg879.2': {17: ('Marjan', 'Marjan'),
#   18: ('Šarec', 'Šarec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg879.9': {4: ('Periča', 'Perič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg879.17': {6: ('Mateja', 'Matej'),
#   7: ('Tonina', 'Tonin')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg879.20': {3: ('Lojze', 'Lojze'),
#   4: ('Janko', 'Janko')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg881.1': {1: ('Dušan', 'Dušan'),
#   2: ('Šiško', 'Šiško')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg883.2': {3: ('Levice', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg883.10': {6: ('Jani', 'Jani'),
#   8: ('Grega', 'Grega'),
#   10: ('Danijel', 'Danijel'),
#   12: ('Matjaž', 'Matjaž')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg883.11': {4: ('Anže', 'Anže'),
#   9: ('Jelka', 'Jelka')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg884.1': {3: ('Luka', 'Luka'),
#   4: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg889.1': {1: ('Trček', 'Trček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg891.3': {4: ('Trček', 'Trček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg891.6': {17: ('SAB', 'SAB')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg891.7': {9: ('Janez', 'Janez'),
#   10: ('Janša', 'Janša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg892.1': {1: ('Trček', 'Trček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg896.1': {1: ('Trček', 'Trček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg897.1': {10: ('Pojbič', 'Pojbič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg899.1': {13: ('Janiju', 'Jani')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg899.2': {15: ('Levica', 'Levica')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg900.1': {1: ('Trček', 'Trček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg901.1': {1: ('Nataša', 'Nataša'),
#   2: ('Sukič', 'Sukič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg904.1': {1: ('Baković', 'Baković')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg907.1': {1: ('Baković', 'Baković')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg910.1': {1: ('Kordiš', 'Kordiš')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg914.3': {3: ('Janeza', 'Janez'),
#   4: ('Janšo', 'Janša'),
#   12: ('Zdravka', 'Zdravko'),
#   13: ('Počivalška', 'Počivalšek')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg914.5': {13: ('Zdravko', 'Zdravko'),
#   14: ('Počivalšek', 'Počivalšek'),
#   16: ('Janeza', 'Janez'),
#   17: ('Janše', 'Janša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg915.1': {1: ('Matjaž', 'Matjaž')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg916.1': {5: ('Igor', 'Igor')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg917.1': {1: ('Matjaž', 'Matjaž')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg918.1': {1: ('Muršič', 'Muršič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg920.7': {4: ('Periča', 'Perič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg922.1': {1: ('Marko', 'Marko'),
#   2: ('Koprivc', 'Koprivc')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg931.1': {1: ('Koprivc', 'Koprivc')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg935.2': {23: ('Janeza', 'Janez'),
#   24: ('Janše', 'Janša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg935.4': {13: ('Janeza', 'Janez'),
#   14: ('Janše', 'Janša')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg943.1': {23: ('Janiju', 'Jani'),
#   24: ('Möderndorferju', 'Möderndorfer'),
#   32: ('Dušan', 'Dušan'),
#   33: ('Verbič', 'Verbič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg943.2': {8: ('Gregorju', 'Gregor'),
#   9: ('Židanu', 'Židan'),
#   16: ('Mateja', 'Mateja'),
#   17: ('Udovč', 'Udovč')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg950.1': {11: ('Vlade', 'vlada'),
#   12: ('Janeza', 'Janez'),
#   14: ('Ivana', 'Ivan'),
#   16: ('Janše', 'Janša'),
#   20: ('Janija', 'Jani'),
#   21: ('Möderndorferja', 'Möderndorfer')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg954.1': {11: ('Vlade', 'vlada'),
#   12: ('Janeza', 'Janez'),
#   14: ('Ivana', 'Ivan'),
#   16: ('Janše', 'Janša'),
#   20: ('Janija', 'Jani'),
#   21: ('Prednika', 'Prednik')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg958.1': {11: ('Vlade', 'vlada'),
#   12: ('Janeza', 'Janez'),
#   14: ('Ivana', 'Ivan'),
#   16: ('Janše', 'Janša'),
#   20: ('Violete', 'Violeta'),
#   21: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg962.1': {21: ('Janeza', 'Janez'),
#   22: ('Ciglerja', 'Cigler'),
#   23: ('Kralja', 'Kralj'),
#   27: ('Jerce', 'Jerca'),
#   28: ('Korče', 'Korče')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg966.1': {13: ('Tomaža', 'Tomaž'),
#   14: ('Gantarja', 'Gantar'),
#   27: ('Janeza', 'Janez'),
#   28: ('Ciglerja', 'Cigler'),
#   29: ('Kralja', 'Kralj'),
#   33: ('Primoža', 'Primož'),
#   34: ('Siterja', 'Siter')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg970.1': {13: ('Jerneja', 'Jernej'),
#   14: ('Vrtovca', 'Vrtovec'),
#   18: ('Dušana', 'Dušan'),
#   19: ('Šiška', 'Šiško')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg974.1': {21: ('Janeza', 'Janez'),
#   22: ('Ciglarja', 'Ciglar'),
#   23: ('Kralja', 'Kralj'),
#   27: ('Braneta', 'Brane'),
#   28: ('Golubovića', 'Golubović')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg978.1': {13: ('Jerneja', 'Jernej'),
#   14: ('Vrtovca', 'Vrtovec'),
#   19: ('Meire', 'Meire'),
#   20: ('Hot', 'Hot')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg982.1': {15: ('Anžeta', 'Anže'),
#   16: ('Logarja', 'Logar'),
#   20: ('Nataše', 'Nataša'),
#   21: ('Sukič', 'Sukič'),
#   38: ('Viktorja', 'Viktor'),
#   39: ('Orbana', 'Orban')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg986.1': {13: ('Tomaža', 'Tomaž'),
#   14: ('Gantarja', 'Gantar'),
#   18: ('Roberta', 'Robert'),
#   19: ('Pavšiča', 'Pavšič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg990.1': {14: ('Andreja', 'Andrej'),
#   15: ('Širclja', 'Šircej'),
#   19: ('Luka', 'Luka'),
#   20: ('Mesca', 'Mesec')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg994.1': {14: ('Boštjana',
#    'Boštjan'),
#   15: ('Koritnika', 'Koritnik'),
#   28: ('Janeza', 'Janez'),
#   29: ('Ciglerja', 'Cigler'),
#   30: ('Kralja', 'Kralj'),
#   34: ('Nika', 'Nika'),
#   35: ('Prebila', 'prebiti')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg998.1': {18: ('Simone', 'Simona'),
#   19: ('Kustec', 'Kustec'),
#   20: ('Lipicer', 'Lipicer'),
#   24: ('Maše', 'Maša'),
#   25: ('Kociper', 'Kociper')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1002.1': {14: ('Andreja', 'Andrej'),
#   15: ('Širclja', 'Šircej'),
#   19: ('Igorja', 'Igor'),
#   20: ('Pečka', 'Peček')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1006.1': {13: ('Tomaža', 'Tomaž'),
#   14: ('Gantarja', 'Gantar'),
#   19: ('Bojane', 'Bojana'),
#   20: ('Muršič', 'Muršič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1010.1': {18: ('Aleksandre',
#    'Aleksandra'),
#   19: ('Pivec', 'Pivec'),
#   23: ('Boštjana', 'Boštjan'),
#   24: ('Koražije', 'Koražija')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1014.1': {14: ('Andreja', 'Andrej'),
#   15: ('Širclja', 'Šircej'),
#   19: ('Marka', 'Marko'),
#   20: ('Bandellija', 'Bandelli')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1018.1': {14: ('Boštjana',
#    'Boštjan'),
#   15: ('Koritnika', 'Koritnik'),
#   19: ('Rudija', 'Rudi'),
#   20: ('Medveda', 'Medved')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1022.1': {18: ('Simone', 'Simona'),
#   19: ('Kustec', 'Kustec'),
#   20: ('Lipicer', 'Lipicer'),
#   24: ('Aljaža', 'Aljaž'),
#   25: ('Kovačiča', 'Kovačič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1026.1': {13: ('Tomaža', 'Tomaž'),
#   14: ('Gantarja', 'Gantar'),
#   18: ('Željka', 'Željko'),
#   19: ('Ciglerja', 'Cigler')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1030.1': {14: ('Andreja', 'Andrej'),
#   15: ('Širclja', 'Šircej'),
#   19: ('Andreje', 'Andreja'),
#   20: ('Zabret', 'Zabret')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1034.1': {13: ('Tomaža', 'Tomaž'),
#   14: ('Gantarja', 'Gantar'),
#   18: ('Vojka', 'Vojko'),
#   19: ('Starovića', 'Starović')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1038.1': {14: ('Vaska', 'Vasko'),
#   15: ('Simonitija', 'Simoniti'),
#   19: ('Lidije', 'Lidija'),
#   20: ('Divjak', 'Divjak'),
#   21: ('Mirnik', 'Mirnik')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1042.1': {16: ('Andreja', 'Andrej'),
#   17: ('Vizjaka', 'Vizjak'),
#   21: ('Mihe', 'Miha'),
#   22: ('Kordiša', 'Kordiš')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1046.1': {13: ('Jerneja', 'Jernej'),
#   14: ('Vrtovca', 'Vrtovec'),
#   18: ('Edvarda', 'Edvard'),
#   19: ('Pauliča', 'Paulič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1050.1': {18: ('Aleksandre',
#    'Aleksandra'),
#   19: ('Pivec', 'Pivec'),
#   24: ('Andreja', 'Andrej'),
#   25: ('Rajha', 'Rajh')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1054.1': {13: ('Tomaža', 'Tomaž'),
#   14: ('Gantarja', 'Gantar'),
#   18: ('Roberta', 'Robert'),
#   19: ('Pavšiča', 'Pavšič')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1058.1': {16: ('Andreja', 'Andrej'),
#   17: ('Vizjaka', 'Vizjak'),
#   21: ('Željka', 'Željko'),
#   22: ('Ciglerja', 'Cigler')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1062.1': {13: ('Jerneja', 'Jernej'),
#   14: ('Vrtovca', 'Vrtovec'),
#   19: ('Andreja', 'Andrej'),
#   20: ('Rajha', 'Rajh')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1066.1': {15: ('Anžeta', 'Anže'),
#   16: ('Logarja', 'Logar'),
#   20: ('Nika', 'Nika'),
#   21: ('Prebila', 'prebiti')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1070.1': {14: ('Andreja', 'Andrej'),
#   15: ('Širclja', 'Šircej'),
#   19: ('Andreje', 'Andreja'),
#   20: ('Zabret', 'Zabret')},
#  'ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg1074.1': {14: ('Vaska', 'Vasko'),
#   15: ('Simonitija', 'Simoniti'),
#   19: ('Violete', 'Violeta'),
#   20: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg3.1': {16: ('Marija', 'Marija'),
#   17: ('Antonija', 'Antonija'),
#   18: ('Kovačič', 'Kovačič'),
#   21: ('Irena', 'Irena'),
#   22: ('Kotnik', 'Kotnik'),
#   28: ('Milan', 'Milan'),
#   29: ('Brglez', 'Brglez'),
#   36: ('László', 'László'),
#   37: ('Göncz', 'Göncz'),
#   40: ('Matej', 'Matej'),
#   41: ('Tonin', 'Tonin'),
#   44: ('Janez', 'Janez'),
#   45: ('Janša', 'Janša'),
#   48: ('Franc', 'Franc'),
#   49: ('Trček', 'Trček'),
#   55: ('Branko', 'Branko'),
#   56: ('Zorman', 'Zorman'),
#   62: ('Igor', 'Igor'),
#   63: ('Zorčič', 'Zorčič'),
#   69: ('Matej', 'Matej'),
#   70: ('T.', 't.'),
#   71: ('Vatovec', 'Vatovec')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg5.1': {15: ('Janijem', 'Jani'),
#   16: ('Möderndorferjem', 'Möderndorfer')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg6.1': {5: ('Urški', 'Urška'),
#   6: ('Ban', 'Ban')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg15.1': {7: ('Janiju', 'Jani'),
#   8: ('Möderndorferju', 'Möderndorfer')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg23.1': {20: ('Metodu', 'Metod'),
#   21: ('Dragonji', 'Dragonja')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg30.1': {12: ('Jožef', 'Jožef'),
#   13: ('Horvat', 'Horvat')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg37.1': {10: ('Bojan', 'Bojan'),
#   11: ('Krajnc', 'Krajnc')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg44.1': {10: ('Suzana', 'Suzana'),
#   11: ('Lep', 'lep'),
#   12: ('Šimenko', 'Šimenko')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg49.1': {11: ('Uroš', 'Uroš'),
#   12: ('Prikl', 'Prikl')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg57.1': {9: ('Marija', 'Marija'),
#   10: ('Bačič', 'Bačič')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg63.1': {8: ('Luka', 'Luka'),
#   9: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg72.1': {15: ('Lukom', 'Luka'),
#   16: ('Mesecem', 'Mesec')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg73.1': {5: ('Tilnu', 'Tilen'),
#   6: ('Božiču', 'Božič')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg75.1': {47: ('Lukom', 'Luka'),
#   48: ('Mesecem', 'Mesec')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg82.1': {6: ('Luki', 'Luka'),
#   7: ('Mescu', 'Mesec')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg91.1': {20: ('Metodu', 'Metod'),
#   21: ('Dragonji', 'Dragonja')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg97.1': {9: ('Alenka', 'Alenka'),
#   10: ('Bratušek', 'Bratušek')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg102.1': {17: ('Gursa', 'Gurs')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg102.3': {7: ('Cerarja', 'Cerar')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg104.1': {10: ('Franc', 'Franc'),
#   11: ('Laj', 'Laj')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg106.1': {21: ('Luko', 'Luka'),
#   22: ('Mescem', 'Mesec')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg111.1': {10: ('Marko', 'Marko'),
#   11: ('Pogačnik', 'Pogačnik')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg114.1': {7: ('Mira', 'Miro'),
#   8: ('Cerarja', 'Cerar')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg114.2': {14: ('Mira', 'Miro'),
#   15: ('Cerarja', 'Cerar')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg115.1': {10: ('Mira', 'Miro'),
#   11: ('Cerarja', 'Cerar')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg116.1': {11: ('Uroš', 'Uroš'),
#   12: ('Prikl', 'Prikl')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg122.1': {9: ('Janko', 'Janko'),
#   10: ('Veber', 'Veber')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg129.1': {8: ('Luka', 'Luka'),
#   9: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg132.2': {27: ('Mira', 'Miro'),
#   28: ('Cerarja', 'Cerar')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg137.1': {12: ('Jožef', 'Jožef'),
#   13: ('Horvat', 'Horvat')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg146.2': {17: ('Metodu', 'Metod'),
#   18: ('Dragonji', 'Dragonja')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg147.1': {11: ('Ireni', 'Irena'),
#   12: ('Sodin', 'Sodin')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg153.2': {8: ('Tilnu', 'Tilen'),
#   9: ('Božiču', 'Božič')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg161.2': {3: ('Dušan', 'Dušan'),
#   4: ('Verbič', 'Verbič')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg167.1': {10: ('Suzana', 'Suzana'),
#   11: ('Lep', 'lep'),
#   12: ('Šimenko', 'Šimenko')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg174.1': {11: ('Uroš', 'Uroš'),
#   12: ('Prikl', 'Prikl')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg176.8': {13: ('Sodinova',
#    'Sodinov')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg180.1': {10: ('Janko', 'Janko'),
#   11: ('Veber', 'Veber')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg185.1': {8: ('Miha', 'Miha'),
#   9: ('Kordiš', 'Kordiš')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg192.1': {12: ('Jožef', 'Jožef'),
#   13: ('Horvat', 'Horvat')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg197.1': {9: ('Alenka', 'Alenka'),
#   10: ('Bratušek', 'Bratušek')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg208.1': {1: ('Luka', 'Luka'),
#   2: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg220.1': {1: ('Dušan', 'Dušan'),
#   2: ('Verbič', 'Verbič')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg231.1': {3: ('Janko', 'Janko'),
#   4: ('Veber', 'Veber')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg235.1': {3: ('Jani', 'Jani'),
#   4: ('Möderndorfer', 'Möderndorfer')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg237.13': {8: ('Mesec', 'mesec'),
#   26: ('Mencingerja', 'Mencinger')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg240.1': {1: ('Uroš', 'Uroš'),
#   2: ('Prikl', 'Prikl')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg246.1': {3: ('Jožef', 'Jožef'),
#   4: ('Horvat', 'Horvat')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg248.1': {9: ('Janija', 'Jani'),
#   10: ('Möderndorferja', 'Möderndorfer')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg252.1': {1: ('Luka', 'Luka'),
#   2: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg257.1': {2: ('Dušan', 'Dušan'),
#   3: ('Verbič', 'Verbič')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg261.1': {2: ('Luka', 'Luka'),
#   3: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg265.1': {3: ('Uroš', 'Uroš'),
#   4: ('Prikl', 'Prikl')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg267.1': {1: ('Horvat', 'Horvat')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg269.1': {8: ('Irena', 'Irena'),
#   9: ('Sodin', 'Sodin')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg273.1': {6: ('Horvatu', 'Horvat')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg275.1': {1: ('Luka', 'Luka'),
#   2: ('Mesec', 'Mesec')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg282.1': {14: ('Jožetom', 'Jože'),
#   15: ('Tankom', 'Tanko')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg282.2': {14: ('Jožetom', 'Jože'),
#   15: ('Tankom', 'Tanko')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg283.1': {12: ('Evi', 'Eva'),
#   13: ('Irgl', 'Irgl')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg285.2': {20: ('Uroš', 'Uroš'),
#   21: ('Grilc', 'Grilc')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg286.1': {18: ('Tamara', 'Tamara'),
#   19: ('Griesser', 'Griesser'),
#   20: ('Pečar', 'Pečar')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg288.1': {12: ('Julijani',
#    'Julijana'),
#   13: ('Bizjak', 'Bizjak'),
#   14: ('Mlakar', 'Mlakar')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg293.1': {12: ('Andrej', 'Andrej'),
#   13: ('Čuš', 'Čuš')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg295.8': {22: ('Grilca', 'Grilc')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg296.6': {3: ('Igor', 'Igor'),
#   4: ('Omerza', 'Omerza'),
#   15: ('Edvardu', 'Edvard'),
#   16: ('Kocbeku', 'Kocbek')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg296.7': {8: ('Boruta', 'Borut'),
#   9: ('Pahorja', 'Pahor')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg296.9': {14: ('Grilc', 'Grilc')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg296.14': {12: ('Grilc', 'Grilc')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg296.16': {2: ('Tamara', 'Tamara'),
#   3: ('Griesser', 'Griesser'),
#   4: ('Pečar', 'Pečar')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg296.36': {17: ('Stéphane',
#    'Stéphane'),
#   18: ('Courtois', 'Courtois')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg298.1': {13: ('Primož', 'Primož'),
#   14: ('Hainz', 'Hainz')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg301.4': {10: ('Evo', 'Eva'),
#   11: ('Irgl', 'Irgl')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg303.1': {11: ('Marija', 'Marija'),
#   12: ('Bačič', 'Bačič')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg309.1': {10: ('Violeta', 'Violeta'),
#   11: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg312.5': {31: ('Danila', 'Danilo'),
#   32: ('Türka', 'Türk')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg314.1': {14: ('Ljudmila',
#    'Ljudmila'),
#   15: ('Novak', 'Novak')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg319.1': {11: ('Bojan', 'Bojan'),
#   12: ('Dobovšek', 'Dobovšek')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg323.1': {12: ('Anita', 'Anita'),
#   13: ('Koleša', 'Koleša')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg329.1': {3: ('Jelka', 'Jelka'),
#   4: ('Godec', 'Godec'),
#   10: ('Janja', 'Janja'),
#   11: ('Sluga', 'Sluga')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg331.3': {21: ('Pahor', 'Pahor')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg335.1': {3: ('Janja', 'Janja'),
#   4: ('Sluga', 'Sluga')},
#  'ParlaMint-SI_2015-09-22-SDZ7-Redna-11.seg340.1': {3: ('Matjaž', 'Matjaž'),
# ...
#    'Shamieh')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg127.6': {38: ('Kontič', 'Kontič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg133.1': {5: ('Igor', 'Igor'),
#   6: ('Zorčič', 'Zorčič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg134.1': {9: ('Anjo', 'Anja'),
#   10: ('Bah', 'Bah'),
#   11: ('Žibert', 'Žibert'),
#   35: ('Shamieha', 'Shamieh')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg135.1': {1: ('Anja', 'Anja'),
#   2: ('Bah', 'Bah'),
#   3: ('Žibert', 'Žibert')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg136.1': {3: ('Anja', 'Anja'),
#   4: ('Bah', 'Bah'),
#   5: ('Žibert', 'Žibert')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg138.1': {10: ('Shamieh',
#    'Shamieh')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg140.2': {6: ('Vesna', 'Vesna'),
#   7: ('Györkös', 'Györkös'),
#   8: ('Žnidar', 'Žnidar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg143.1': {7: ('Novak', 'Novak')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg145.1': {2: ('Novakova',
#    'Novakov')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg145.3': {34: ('Novak', 'Novak')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg146.1': {8: ('Gorenak', 'Gorenak')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg147.1': {9: ('Gorenaka',
#    'Gorenak')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg147.7': {1: ('Grims', 'Grims')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg147.11': {5: ('Dublinska',
#    'dublinski')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg151.1': {5: ('Branko', 'Branko'),
#   6: ('Grims', 'Grims')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg154.18': {22: ('Erdogan',
#    'Erdogan')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg154.23': {12: ('Erdogan',
#    'Erdogan')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg156.2': {2: ('Tanja', 'Tanja'),
#   3: ('Fajon', 'Fajon')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg157.1': {22: ('Slovenk',
#    'Slovenka'),
#   24: ('Slovencev', 'Slovenec')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg157.14': {7: ('Slovenka',
#    'Slovenka'),
#   10: ('Slovenec', 'Slovenec')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg157.15': {6: ('Slovenk',
#    'Slovenka'),
#   8: ('Slovencev', 'Slovenec')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg163.1': {15: ('Milanom', 'Milan'),
#   16: ('Brglezom', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg164.1': {15: ('Milanom', 'Milan'),
#   16: ('Brglezom', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg165.1': {10: ('Milanu', 'Milan'),
#   11: ('Brglezu', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg173.1': {1: ('Igor', 'Igor'),
#   2: ('Zorčič', 'Zorčič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg176.6': {26: ('Slovencem',
#    'Slovenec')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg177.1': {11: ('Milanom', 'Milan'),
#   12: ('Brglezom', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg179.1': {1: ('Marijan', 'Marijan'),
#   2: ('Pojbič', 'Pojbič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg186.1': {1: ('Peter', 'Peter'),
#   2: ('Vilfan', 'Vilfan')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg190.1': {1: ('Brglez', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg191.9': {23: ('Brglez', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg195.1': {1: ('Matjaž', 'Matjaž'),
#   2: ('Han', 'Han')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg201.1': {0: ('Milan', 'Milan')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg202.1': {10: ('Violeta', 'Violeta'),
#   11: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg206.1': {10: ('Cerarja', 'Cerar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg206.3': {1: ('Cerar', 'Cerar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg206.5': {15: ('Britancev',
#    'Britanec')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg206.8': {14: ('Klemenčiča',
#    'Klemenčič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg206.10': {40: ('Brglezom',
#    'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg207.2': {1: ('Mira', 'Miro'),
#   2: ('Cerarja', 'Cerar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg207.7': {3: ('Brglez', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg207.9': {8: ('Brglez', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg207.13': {1: ('Mira', 'Miro'),
#   2: ('Cerarja', 'Cerar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg207.21': {1: ('Levico', 'Levica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg207.25': {15: ('Brglez', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg208.7': {1: ('Levici', 'Levica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg208.11': {5: ('Levice', 'levica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg208.12': {1: ('Levica', 'Levica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg212.1': {3: ('Milan', 'Milan'),
#   4: ('Brglez', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg219.1': {3: ('Violeta', 'Violeta'),
#   4: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg220.1': {7: ('Brgleza', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg221.4': {40: ('Cerar', 'Cerar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg223.1': {5: ('Marinka', 'Marinka'),
#   6: ('Levičar', 'Levičar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg225.7': {7: ('Violeta', 'Violeta')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg227.1': {3: ('Matjaž', 'Matjaž'),
#   4: ('Han', 'Han')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg229.3': {2: ('Milan', 'Milan')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg231.1': {3: ('Violeta', 'Violeta'),
#   4: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg234.4': {2: ('Brglez', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg234.17': {7: ('Han', 'Han')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg236.3': {6: ('Levici', 'Levica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg236.4': {2: ('Brglez', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg236.18': {31: ('Slovenci',
#    'Slovenec')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg237.1': {5: ('Igor', 'Igor'),
#   6: ('Zorčič', 'Zorčič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg244.1': {3: ('Violeta', 'Violeta'),
#   4: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg246.1': {1: ('Zorčiču', 'Zorčič'),
#   22: ('Desusom', 'Desus')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg247.1': {1: ('Levici', 'Levica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg247.2': {27: ('Slovenci',
#    'Slovenec')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg247.4': {2: ('Levici', 'Levica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg248.1': {8: ('Violeta', 'Violeta'),
#   9: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg249.1': {1: ('Matjaž', 'Matjaž'),
#   2: ('Han', 'Han')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg251.1': {13: ('Zorčič', 'Zorčič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg251.5': {4: ('Igor', 'Igor')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg252.1': {5: ('Matjaž', 'Matjaž'),
#   6: ('Han', 'Han')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg253.1': {2: ('Julijana',
#    'Julijana'),
#   3: ('Bizjak', 'Bizjak'),
#   4: ('Mlakar', 'Mlakar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg255.4': {5: ('Brgleza', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg258.1': {1: ('Milan', 'Milan'),
#   2: ('Brglez', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg263.9': {6: ('Wilfrida', 'Wilfrid'),
#   7: ('Lauriera', 'Laurier')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg266.1': {3: ('Julijana',
#    'Julijana'),
#   4: ('Bizjak', 'Bizjak'),
#   5: ('Mlakar', 'Mlakar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg270.1': {3: ('Violeta', 'Violeta'),
#   4: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg273.1': {1: ('Brglez', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg273.3': {3: ('Brgleza', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg273.11': {6: ('Levici', 'Levica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg274.3': {27: ('Nemcem', 'Nemec')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg274.5': {3: ('Grki', 'Grk')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg274.12': {1: ('Brglez', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg275.1': {3: ('Igor', 'Igor'),
#   4: ('Zorčič', 'Zorčič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg278.6': {17: ('Desus', 'DeSUS')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg279.4': {1: ('Han', 'Han')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg279.7': {38: ('Slovenci',
#    'Slovenec')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg279.10': {7: ('Ivice', 'Ivica'),
#   8: ('Žnidaršič', 'Žnidaršič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg280.1': {3: ('Milan', 'Milan'),
#   4: ('Brglez', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg280.3': {1: ('Julijana',
#    'Julijana'),
#   2: ('Bizjak', 'Bizjak'),
#   3: ('Mlakar', 'Mlakar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg281.1': {1: ('Milan', 'Milan'),
#   2: ('Brglez', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg285.1': {3: ('Julijana',
#    'Julijana'),
#   4: ('Bizjak', 'Bizjak'),
#   5: ('Mlakar', 'Mlakar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg287.1': {8: ('Zorčiča', 'Zorčič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg287.3': {10: ('Zorčič', 'Zorčič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg287.4': {4: ('Ivice', 'Ivica'),
#   5: ('Žnidaršič', 'Žnidaršič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg293.1': {28: ('Petru', 'Petar'),
#   29: ('Pogačarju', 'Pogačar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg305.1': {12: ('Urošu', 'Uroš'),
#   13: ('Priklu', 'Prikel')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg318.1': {11: ('Saša', 'Saša'),
#   12: ('Tabaković', 'Tabaković')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg323.1': {1: ('Marijan', 'Marijan'),
#   2: ('Pojbič', 'Pojbič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg329.1': {1: ('Uroš', 'Uroš'),
#   2: ('Prikl', 'Prikl')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg334.3': {28: ('Slovenci',
#    'Slovenec')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg336.1': {1: ('Marija', 'Marija'),
#   2: ('Bačič', 'Bačič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg343.1': {1: ('Miha', 'Miha'),
#   2: ('Kordiš', 'Kordiš')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg347.1': {1: ('Levici', 'Levica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg347.17': {17: ('Peter', 'Peter'),
#   18: ('Pogačar', 'Pogačar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg354.1': {20: ('Jožici', 'Jožica'),
#   21: ('Maučec', 'Maučec'),
#   22: ('Zakotnik', 'Zakotnik')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg365.1': {8: ('Marijanu', 'Marijan'),
#   9: ('Pojbiču', 'Pojbič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg369.1': {6: ('Jožica', 'Jožica'),
#   7: ('Maučec', 'Maučec'),
#   8: ('Zakotnik', 'Zakotnik')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg370.1': {3: ('Nataša', 'Nataša'),
#   4: ('Voršič', 'Voršič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg371.1': {17: ('Peter', 'Peter'),
#   18: ('Požun', 'Požun')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg378.1': {1: ('Nada', 'Nada'),
#   2: ('Brinovšek', 'Brinovšek')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg381.5': {10: ('Slovence',
#    'Slovenec')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg385.1': {1: ('Tomaž', 'Tomaž'),
#   2: ('Gantar', 'Gantar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg388.6': {19: ('Slovenk',
#    'Slovenka'),
#   21: ('Slovencev', 'Slovenec')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg391.1': {1: ('Bojana', 'Bojana'),
#   2: ('Muršič', 'Muršič')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg397.1': {1: ('Miha', 'Miha'),
#   2: ('Kordiš', 'Kordiš')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg399.4': {1: ('Levice', 'levica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg399.10': {3: ('Anje', 'Anja'),
#   4: ('Kopač', 'Kopač'),
#   5: ('Mrak', 'Mrak')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg400.1': {1: ('Levice', 'Levica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg400.2': {19: ('Levice', 'Levica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg404.1': {1: ('Jasna', 'Jasna'),
#   2: ('Murgel', 'Murgel')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg417.1': {11: ('Branko', 'Branko'),
#   12: ('Grims', 'Grims')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg424.1': {8: ('Violeta', 'Violeta'),
#   9: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg425.1': {1: ('Levice', 'Levica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg425.6': {14: ('Borut', 'Borut'),
#   15: ('Pahor', 'Pahor')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg425.7': {2: ('Brgleza', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg425.10': {8: ('Brglez', 'Brglez')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg427.1': {7: ('Marjana', 'Marjana'),
#   8: ('Kotnik', 'Kotnik'),
#   9: ('Poropat', 'Poropat')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg430.2': {10: ('Violeta',
#    'Violeta')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg430.3': {7: ('Führer', 'Führer')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg432.1': {7: ('Julijana',
#    'Julijana'),
#   8: ('Bizjak', 'Bizjak'),
#   9: ('Mlakar', 'Mlakar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg435.1': {7: ('Janko', 'Janko'),
#   8: ('Veber', 'Veber')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg451.1': {8: ('Violeta', 'Violeta'),
#   9: ('Tomić', 'Tomić')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg453.3': {1: ('Levici', 'Levica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg455.1': {11: ('Dragan', 'Dragan'),
#   12: ('Matić', 'Matić')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg460.1': {7: ('Julijana',
#    'Julijana'),
#   8: ('Bizjak', 'Bizjak'),
#   9: ('Mlakar', 'Mlakar')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg462.4': {0: ('Slovenci',
#    'Slovenec')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg468.1': {11: ('Branko', 'Branko'),
#   12: ('Grims', 'Grims')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg479.1': {10: ('Mojce', 'Mojca'),
#   11: ('Muha', 'Muha')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg480.1': {12: ('Maji', 'Maja'),
#   13: ('Rozman', 'Rozman')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg482.1': {26: ('Mojco', 'Mojca'),
#   27: ('Muha', 'Muha')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg483.5': {18: ('Mojca', 'Mojca'),
#   19: ('Muha', 'Muha')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg484.1': {1: ('Mojca', 'Mojca'),
#   2: ('Muha', 'Muha')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg486.1': {13: ('Mojca', 'Mojca'),
#   14: ('Muha', 'Muha')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg487.1': {1: ('Mojca', 'Mojca'),
#   2: ('Muha', 'Muha')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg489.1': {8: ('Mitji', 'Mitja'),
#   9: ('Horvatu', 'Horvat')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg493.1': {9: ('Mojca', 'Mojca'),
#   10: ('Muha', 'Muha')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg495.1': {40: ('Mojca', 'Mojca'),
#   41: ('Muha', 'Muha')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg497.1': {25: ('Mojca', 'Mojca'),
#   26: ('Muha', 'Muha')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg502.1': {9: ('Tadeja', 'Tadej'),
#   10: ('Rebrica', 'Rebric')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg503.1': {12: ('Maji', 'Maja'),
#   13: ('Rozman', 'Rozman')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg504.1': {23: ('Tadeja', 'Tadej'),
#   24: ('Rebrico', 'Rebrica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg505.2': {22: ('Tadej', 'Tadej'),
#   23: ('Rebrica', 'Rebrica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg506.1': {1: ('Tadej', 'Tadej'),
#   2: ('Rebrica', 'Rebrica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg506.5': {7: ('Tadej', 'Tadej'),
#   8: ('Rebrica', 'Rebrica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg507.1': {1: ('Tadej', 'Tadej'),
#   2: ('Rebrica', 'Rebrica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg509.1': {24: ('Tadej', 'Tadej'),
#   25: ('Rebrica', 'Rebrica')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg515.1': {9: ('Mitji', 'Mitja'),
#   10: ('Horvatu', 'Horvat')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg518.4': {21: ('Janeza', 'Janez'),
#   22: ('Čadeža', 'Čadež'),
#   35: ('Lucijo', 'Lucija'),
#   36: ('Šikovec', 'Šikovec'),
#   37: ('Ušaj', 'Ušaj')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg518.5': {40: ('Janez', 'Janez'),
#   41: ('Čadež', 'Čadež')},
#  'ParlaMint-SI_2018-03-27-SDZ7-Redna-39.seg520.1': {41: ('Janez', 'Janez'),
#   42: ('Čadež', 'Čadež')}}

# %%
# Create a dataframe out of this information
names_df = pd.DataFrame({"sentence_id":list(sent_dict.keys()), "proper_nouns": list(sent_dict.values())})

names_df.head()
# Out:
#                                      sentence_id  \
# 0   ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg4.1
# 1   ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg8.1
# 2   ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg9.1
# 3  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg11.1
# 4  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg13.1
#
#                                         proper_nouns
# 0  {4: ('Anji', 'Anja'), 5: ('Bah', 'Bah'), 6: ('...
# 1  {6: ('Marjan', 'Marjan'), 7: ('Maučec', 'Mauče...
# 2   {7: ('Tomaž', 'Tomaž'), 8: ('Gantar', 'Gantar')}
# 3  {2: ('Marjanu', 'Marjan'), 3: ('Maučecu', 'Mau...
# 4  {29: ('Franca', 'Franc'), 30: ('Kanglerja', 'K...

# %%
# Add this information to the main table - sample df

df_sample = pd.merge(df_sample, names_df, on="sentence_id", how="outer")

df_sample.head()
# Out:
#                                            file  \
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 2  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 3  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 4  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
#
#                                     sentence_id  \
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg2.1
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3.1
# 2  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3.2
# 3  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg4.1
# 4  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg5.1
#
#                                                 text  length  \
# 0  Prehajamo na 2. TOČKO DNEVNEGA REDA, TO JE NA ...      28
# 1  Predlog zakona je v obravnavo zboru predložil ...       9
# 2  V zvezi s tem predlogom zakona Odbor za zdravs...      22
# 3  Besedo dajem predsednici odbora Anji Bah Žiber...      12
# 4                          Hvala lepa, predsedujoči.       3
#
#                                        seg_id  \
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg2
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3
# 2  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3
# 3  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg4
# 4  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg5
#
#                                       no_punctuation  \
# 0  Prehajamo na 2 TOČKO DNEVNEGA REDA TO JE NA DR...
# 1  Predlog zakona je v obravnavo zboru predložil ...
# 2  V zvezi s tem predlogom zakona Odbor za zdravs...
# 3  Besedo dajem predsednici odbora Anji Bah Žiber...
# 4                            Hvala lepa predsedujoči
#
#                                        list_of_words  \
# 0  [Prehajamo, na, 2, TOČKO, DNEVNEGA, REDA, TO, ...
# 1  [Predlog, zakona, je, v, obravnavo, zboru, pre...
# 2  [V, zvezi, s, tem, predlogom, zakona, Odbor, z...
# 3  [Besedo, dajem, predsednici, odbora, Anji, Bah...
# 4                        [Hvala, lepa, predsedujoči]
#
#                                         proper_nouns
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  {4: ('Anji', 'Anja'), 5: ('Bah', 'Bah'), 6: ('...
# 4                                                NaN

# %%
df_sample.describe(include="all")
# Out:
#                                                 file  \
# count                                           8217
# unique                                             3
# top     ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# freq                                            3486
# mean                                             NaN
# std                                              NaN
# min                                              NaN
# 25%                                              NaN
# 50%                                              NaN
# 75%                                              NaN
# max                                              NaN
#
#                                          sentence_id         text  \
# count                                           8217         8217
# unique                                          8217         7386
# top     ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg2.1  Hvala lepa.
# freq                                               1          211
# mean                                             NaN          NaN
# std                                              NaN          NaN
# min                                              NaN          NaN
# 25%                                              NaN          NaN
# 50%                                              NaN          NaN
# 75%                                              NaN          NaN
# max                                              NaN          NaN
#
#              length                                        seg_id  \
# count   8217.000000                                          8217
# unique          NaN                                          2055
# top             NaN  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg408
# freq            NaN                                            95
# mean      18.557990                                           NaN
# std       14.180222                                           NaN
# min        1.000000                                           NaN
# 25%        8.000000                                           NaN
# 50%       16.000000                                           NaN
# 75%       26.000000                                           NaN
# max      143.000000                                           NaN
#
#        no_punctuation  list_of_words               proper_nouns
# count            8217           8217                        816
# unique           7373           7373                        721
# top        Hvala lepa  [Hvala, lepa]  {1: ('Levici', 'Levica')}
# freq              212            212                          7
# mean              NaN            NaN                        NaN
# std               NaN            NaN                        NaN
# min               NaN            NaN                        NaN
# 25%               NaN            NaN                        NaN
# 50%               NaN            NaN                        NaN
# 75%               NaN            NaN                        NaN
# max               NaN            NaN                        NaN

# %%
# Save sample file
df_sample.to_csv("Parlamint-SI-sample.csv")

# %% [markdown]
# ### Machine translate

# %%
# Install easynmt
#!pip install -q -U easynmt

# %%
from easynmt import EasyNMT

# Define the model - The system will automatically detect the suitable Opus-MT model and load it.
model = EasyNMT('opus-mt')

# %%
# Create a list of sentences from the df
sentence_list = df_sample.text.to_list()
len(sentence_list)
# Out:
# 8217

# %%
#Translate the list of sentences - you need to provide the source language as it is in the name of the model (zls - South Slavic)
translation_list = model.translate(sentence_list, source_lang = 'zls', target_lang='en')

# Add the translations to the df
df_sample["translation"] = translation_list

df_sample.head()
# Out:
#                                            file  \
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 2  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 3  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
# 4  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.conllu
#
#                                     sentence_id  \
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg2.1
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3.1
# 2  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3.2
# 3  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg4.1
# 4  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg5.1
#
#                                                 text  length  \
# 0  Prehajamo na 2. TOČKO DNEVNEGA REDA, TO JE NA ...      28
# 1  Predlog zakona je v obravnavo zboru predložil ...       9
# 2  V zvezi s tem predlogom zakona Odbor za zdravs...      22
# 3  Besedo dajem predsednici odbora Anji Bah Žiber...      12
# 4                          Hvala lepa, predsedujoči.       3
#
#                                        seg_id  \
# 0  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg2
# 1  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3
# 2  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg3
# 3  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg4
# 4  ParlaMint-SI_2020-05-27-SDZ8-Redna-17.seg5
#
#                                       no_punctuation  \
# 0  Prehajamo na 2 TOČKO DNEVNEGA REDA TO JE NA DR...
# 1  Predlog zakona je v obravnavo zboru predložil ...
# 2  V zvezi s tem predlogom zakona Odbor za zdravs...
# 3  Besedo dajem predsednici odbora Anji Bah Žiber...
# 4                            Hvala lepa predsedujoči
#
#                                        list_of_words  \
# 0  [Prehajamo, na, 2, TOČKO, DNEVNEGA, REDA, TO, ...
# 1  [Predlog, zakona, je, v, obravnavo, zboru, pre...
# 2  [V, zvezi, s, tem, predlogom, zakona, Odbor, z...
# 3  [Besedo, dajem, predsednici, odbora, Anji, Bah...
# 4                        [Hvala, lepa, predsedujoči]
#
#                                         proper_nouns  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  {4: ('Anji', 'Anja'), 5: ('Bah', 'Bah'), 6: ('...
# 4                                                NaN
#
#                                          translation
# 0  Moving to 2. ACT OF DAYS, THIS IS A SECOND DET...
# 1  The proposal for a law was submitted to the As...
# 2  As regards this proposal for a law, the Commit...
# 3  I hereby give the President of the Anji Bah Ži...
# 4                    Thank you very much, President.

# %% [markdown]
# 230 segments (11,158 words) were translated in 19 s -> 10,000 words are translated in 17s. We would need 10 hours to translate the entire ParlaMint-SL.

# %%
# Save the df
df_sample.to_csv("Parlamint-SI-sample-translated.csv", sep = "\t")
