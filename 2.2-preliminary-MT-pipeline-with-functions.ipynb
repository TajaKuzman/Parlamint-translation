# %% [markdown]
# This is the code for the pipeline to get all the files, compare models on a sample, translate all files using the best model and correct proper nouns.

# %% [markdown]
# ## Main code

# %%
import pandas as pd
from IPython.display import display

# %%
lang_code = "SI"
files_path = "/home/tajak/Parlamint-translation/ParlaMint-SI/ParlaMint-SI.TEI.ana"
opus_lang_code = "sla"

# %%
df = extract_text(files_path, lang_code)

df.head()
# Out:
# Number of files is: 414
# Number of words in the corpora: 54734
#                                                      file  \
# count                                                2628
# unique                                                  1
# top     /home/tajak/Parlamint-translation/ParlaMint-SI...
# freq                                                 2628
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                          sentence_id          text  \
# count                                           2628          2628
# unique                                          2628          2494
# top     ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg1.1  Hvala lepa .
# freq                                               1            52
# mean                                             NaN           NaN
# std                                              NaN           NaN
# min                                              NaN           NaN
# 25%                                              NaN           NaN
# 50%                                              NaN           NaN
# 75%                                              NaN           NaN
# max                                              NaN           NaN
#
#        proper_nouns       length
# count          2628  2628.000000
# unique          133          NaN
# top              []          NaN
# freq           2487          NaN
# mean            NaN    20.827245
# std             NaN    14.633807
# min             NaN     2.000000
# 25%             NaN    10.000000
# 50%             NaN    18.000000
# 75%             NaN    28.000000
# max             NaN   104.000000
#                                                 file  \
# 1  /home/tajak/Parlamint-translation/ParlaMint-SI...
# 2  /home/tajak/Parlamint-translation/ParlaMint-SI...
# 3  /home/tajak/Parlamint-translation/ParlaMint-SI...
# 4  /home/tajak/Parlamint-translation/ParlaMint-SI...
# 5  /home/tajak/Parlamint-translation/ParlaMint-SI...
#
#                                     sentence_id  \
# 1  ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg1.1
# 2  ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg2.1
# 3  ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg3.1
# 4  ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg3.2
# 5  ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg4.1
#
#                                                 text  \
# 1  Spoštovane kolegice poslanke , spoštovani kole...
# 2  Začenjam nadaljevanje 12. seje  Državnega zbor...
# 3  Obveščen sem , da se današnje seje ne morejo u...
# 4             Vsem prisotnim še enkrat lep pozdrav !
# 5  Prehajamo na 2. , 3. , 4. IN 5. TOČKO DNEVNEGA...
#
#                                         proper_nouns  length
# 1                                                 []      12
# 2                                                 []       7
# 3  [{15: ['Eva', 'Eva'], 16: ['Irgl', 'Irgl'], 19...      89
# 4                                                 []       7
# 5                                                 []      70

# %%
choose_model(lang_code)
# Out:
# Entire corpus has 2628 sentences and 54734 words.
# Sample files has 20 sentences and 565 words.
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     text  \
# 1                                                                                                                                                                                                                                                                                                                                                                                        Spoštovane kolegice poslanke , spoštovani kolegi poslanci , gospe in gospodje !
# 2                                                                                                                                                                                                                                                                                                                                                                                                                     Začenjam nadaljevanje 12. seje  Državnega zbora  .
# 3   Obveščen sem , da se današnje seje ne morejo udeležiti naslednje poslanke in poslanci :  Eva Irgl  , mag.  Marko Pogačnik  ,  Jernej Vrtovec  od 17. ure dalje ,  Jožef Horvat  ,  Blaž Pavlin  od 18. do 20. ure , dr.  Franc Trček  ,  Violeta Tomić  do 17. ure ,  Jože Tanko  od 16.30 dalje ,  Janja Sluga  od 15. do 18.30 ,  Mateja Udovč  do 18. ure ,  Primož Siter  od 13.30 do 15.30 ,  Suzana Lep Šimenko  ,  Jelka Godec  in  Igor Zorčič  do 12. ure .
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                 Vsem prisotnim še enkrat lep pozdrav !
# 5                Prehajamo na 2. , 3. , 4. IN 5. TOČKO DNEVNEGA REDA – DRUGA OBRAVNAVA PREDLOGA  ZAKONA O SPREMEMBAH  IN DOPOLNITVAH  ZAKONA O DAVKU  OD DOBIČKA OD ODSVOJITVE IZVEDENIH FINANČNIH INSTRUMENTOV , PREDLOGA  ZAKONA O SPREMEMBAH IN DOPOLNITVAH ZAKONA O DAVKU  OD DOHODKOV PRAVNIH OSEB , PREDLOGA  ZAKONA O SPREMEMBAH IN DOPOLNITVAH ZAKONA O DAVČNEM POSTOPKU  IN PREDLOGA  ZAKONA O SPREMEMBAH IN DOPOLNITVAH ZAKONA O DOHODNINI  , NUJNI POSTOPEK .
# 6                                                                                                                                                                                                                                                                                                                                                                                                 Predloge zakonov je v obravnavo  Državnemu zboru  predložila  Vlada  .
# 7                                                                                                                                                                                                                                                                                                                                                                                                 Zato vabim gospoda ministra dr.  Andreja Bertonclja  , da spregovori .
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                           Izvolite , gospod minister .
# 9                                                                                                                                                                                                                                                                                                                                                                                                    Spoštovani predsednik , spoštovane poslanke , spoštovani poslanci !
# 10                                                                                                                                                                                                                                                                                                                                                                 Pred vami je paket sprememb štirih zakonov , ki predstavljajo nov korak v smeri davčne optimizacije .
# 11                                                                                                                                                                                                   V navedeni paket sodijo novela  Zakona o dohodnini  , novela  Zakona o davku od dohodkov pravnih oseb  , novela  Zakona o davku od dobička  od odsvojitve izvedenih finančnih instrumentov , posledično pa so potrebne še spremembe v  Zakonu o davčnem postopku  .
# 12                                                                                                                                                                                                                                                                               Temeljni razlog za spremembe , kar kažejo tako domače kot mednarodne študije , je obstoječa struktura davkov v  Sloveniji  , predvsem na področju davčne obremenitve dela in kapitala .
# 13                                                                                                           Želimo seveda še naprej zagotavljati konkurenčno poslovno okolje in mednarodno primerljiv trg dela , zato s predlaganimi davčnimi ukrepi razbremenjujemo delo , da bodo zaposleni dobili več neto , da bo njihova kupna moč večja , s tem bo večja tudi domača potrošnja in bomo tako vsaj delno nadomestili izpad zaradi zmanjšanja neto domačega izvoza .
# 14                                                                                                                                                                                                                                                                                    Navzlic številnim razpravam tako tistih , ki so za , in tistih , ki so proti predlaganim davčnim spremembam , je naša ocena , da je davčna optimizacija pravi korak v pravo smer .
# 15                                                                                                                                                                                                                                                                                                                                               Naš skupni cilj mora biti , da v  Sloveniji  zagotovimo konkurenčno poslovno okolje in mednarodno primerljiv trg dela .
# 16                                                                                                                                                                                                                                                                                                                                                                                                           Tega seveda ne moremo narediti takoj , lahko pa postopoma .
# 17                                                                                                                                                                                                                                                                                                                                                                     Zato so ukrepi postopni , potekajo v več fazah , predvidoma v obdobju štirih , mogoče petih let .
# 18                                                                                                                                                                                                                                                                       Ne pozabimo , davčna optimizacija je paket , v njega je že vključen prvi regres , to je prva faza , ki so jo soglasno podprli vsi socialni partnerji in je bila v letošnjem letu že izpeljana .
# 19                                                                                                                                                                                             Zaposleni , tisti , iz prvega dohodninskega razreda , so letos kot del davčnih sprememb dobili 141,86 evra več kot leto poprej , tako je manipuliranje s številko slaba 2 evra nepotrebno ; ukrepi so namenjeni zaposlenim in prav je , da ne manipuliramo s številkami .
# 20                                                                                                                                                                                                                                                                                               Zaposleni z minimalno plačo bo tako ob minimalnem regresu dobil cirka 150 evrov več v enem letu , če pa je prejel regres v višini povprečne plače pa do 381 evrov več .
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 translation-sla  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                      Dear fellow Members, distinguished fellow Members, ladies and gentlemen!
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                        I begin the continuation of the 12th meeting of the National Assembly.
# 3                                                                       I am informed that today's meeting cannot be attended by the following Member and Members : Eva Irgl, mag.  Marko Pogačnik, Jernej Vrtovac from 17:00 on, Jožef Horvat, Blaž Pavlin from 18 till 20:00, Dr.  Franc Trček, Violeta Tomić until 17:00, Jože Tanko from 16.30 p.m., Janja Slug from 15.30 p.m. to 18.30 p.m., Mateja Udovč, Primož Siter from 13.30 p.m. to 15.30 p.m., Suzanne Leup Šimenko, Jelka Godec and Igor Zorčič until 12.00 p.m.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                All present and welcome again!
# 5   We're moving to 2, 3, 4. AND 5. Agenda item — Second defence of the proposed law on amendments to and additions to the law on income tax from the recovery of financial institutions carried out, proposal of the law on amendments to the law on tax procedure and amendment of the law on amendments to the law on income of legal persons, proposal of the law on amendments and additions to the law on tax procedure and amendment of the law on income and supplementation of the law on income, necessary procedure.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                             Proposals for laws have been tabled by the Government for consideration by the National Assembly.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                        That is why I invite Minister Andre Bertoncl to speak.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Here you go, Mr. Minister.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Dear President, honourable Members, honourable Members!
# 10                                                                                                                                                                                                                                                                                                                                                                                                                Before you is a package of amendments to the four laws, which constitute a new step towards tax optimisation.
# 11                                                                                                                                                                                                                                                                                    This package includes novels of the Income Act, the amendment of the Law on corporate income tax, the amendment of the Law on profit tax from the removal of derivatives, and, consequently, changes to the Tax Procedure Act are needed.
# 12                                                                                                                                                                                                                                                                                                                                     The fundamental reason for changes, both domestic and international studies, is the existing structure of taxes in Slovenia, particularly in the field of labour and capital tax burden.
# 13                                                                                                                                   We, of course, want to continue to provide a competitive business environment and an internationally comparable labour market, so that the proposed tax measures will burden the work so that employees will get more net so that their purchasing power will increase, thus increasing domestic consumption, and thus at least partially compensate for the loss of net domestic exports.
# 14                                                                                                                                                                                                                                                                                                                                                                 It is our view that tax optimisation is the right step in the right direction that many debates are in favour of and those against the proposed tax changes.
# 15                                                                                                                                                                                                                                                                                                                                                                                            Our common goal must be to ensure a competitive business environment and an internationally comparable labour market in Slovenia.
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Of course we can't do this right now, but we can gradually.
# 17                                                                                                                                                                                                                                                                                                                                                                                                  Therefore, the measures are gradual, taking place in several stages, presumably over a period of four, possibly five years.
# 18                                                                                                                                                                                                                                                                                                     Let us not forget, tax optimization is a package, it already includes the first regress, this is the first phase which has been unanimously supported by all social partners and has already been implemented this year.
# 19                                                                                                                                                                                                                                                                    Employees, who, from the first income class, received 141.86 euros more than a year ago as part of the tax changes, so manipulating the 2 euro bad number is unnecessary ; measures are intended for employees and it is right not to manipulate numbers.
# 20                                                                                                                                                                                                                                                                                                                                                                                          Employees with minimum wage will receive a circus of 150 euros more in one year, and if they receive a regress of up to € 381 more.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      translation-zls
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                              Dear fellow Members, honourable fellow Members, ladies and gentlemen!
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                         I am starting a continuation of the 12th meeting of the National Assembly.
# 3                                                                                   I am informed that today's meeting cannot be attended by the following Members and Members: Eva Irgl, mag.  Marko Pogačnik, Jernej Vrtovac from 17:00, Jožef Horvat, Blaž Pavlin from 18 to 20:00, dr.  Franc Trček, Violeta Tomić until 17:00, Jože Tanko from 16:30 onwards, Janja Serva from 15:30, Mateja Udovč  to 18:00, Primož Siter from 13:30 to 15:30, Suzanne Lepo Š imenko, Jelka Godec and Igor Zorčič until 12:00.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       I'm here to say hello again!
# 5   Moving to 2, 3, 4. AND 5. DETECTION OF THE DAY – OTHER DECLARATION OF THE PROGRAMME OF THE COURT ON AMENDMENTS AND DEFINITIONS OF THE INVESTIGATION OF THE IMPLEMENTATION OF THE FINANCIAL INSTRUMENTS, THE PROPOSING OF THE LAW ON THE AMENDMENTS AND THE SUPPORT OF THE LAW ON THE INVESTIGATION OF THE IMPLEMENTS AND THE SUPPORT OF THE LAWS ON THE IMPLEMENTS OF THE IMPLEMENTS AND THE SUPPORT OF THE IMPLEMENTS ON THE IMPLEMENTS AND ADDITION OF THE LAW ON ACCOUNTMENTS ON ACCOUNTMENT, THE IMPLEMENTS.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                    Proposals for laws were submitted by the Government to the National Assembly for consideration.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                        That is why I invite Mr. Minister Andrew Bertoncl to speak.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Here you go, Mr. Minister.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                            Dear President, honourable Members, honourable Members!
# 10                                                                                                                                                                                                                                                                                                                                                                                                      In front of you is a package of amendments to four laws which represent a new step towards tax optimization.
# 11                                                                                                                                                                                                                                                                           That package includes the novels of the Income Act, the novels of the Law on corporate income tax, the novels of the Tax on Profits Act from the disposal of derivatives, and consequently changes are needed in the Tax Procedure Act.
# 12                                                                                                                                                                                                                                                                                                                   The main reason for the changes, as shown in both domestic and international studies, is the existing tax structure in Slovenia, particularly in the field of tax burden on labour and capital.
# 13                                                                                                                 Of course, we want to continue to provide a competitive business environment and an internationally comparable labour market, so the proposed tax measures relieve the work to make employees more net in order to increase their purchasing power, thus increasing domestic consumption, so that we can at least partially compensate for the loss due to the reduction of net domestic exports.
# 14                                                                                                                                                                                                                                                                                                                In spite of many discussions, such as those that are for, and those who are against the proposed tax changes, it is our assessment that tax optimization is the right step in the right direction.
# 15                                                                                                                                                                                                                                                                                                                                                                            Our common objective must be to ensure a competitive business environment and an internationally comparable labour market in Slovenia.
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                       Of course we can't do this right now, but we can gradually.
# 17                                                                                                                                                                                                                                                                                                                                                                               Therefore, measures are gradual, taking place in several phases, expected to take place over a period of four, possibly five years.
# 18                                                                                                                                                                                                                                                                              Let us not forget, tax optimization is a package, it is already included in the first regression, this is the first phase, which was unanimously supported by all the social partners and has already been carried out in this year.
# 19                                                                                                                                                                                                                                                                             Employees from the first income class received 141.86 euros more than a year earlier, so the manipulation of a 2 euro number is unnecessary ; measures are intended for employees, and it is right that we do not manipulate numbers.
# 20                                                                                                                                                                                                                                                                                                                                           The employee will receive a minimum wage of EUR 150 more in one year at the minimum regression, and if he has received a regress of an average salary of up to EUR 381.

# %%
translate(lang_code, "sla")
# Out:
# Entire corpus has 2628 sentences and 54734 words.
# |    | file                                                                                                              | sentence_id                                  | text                                                                                                                                                                                                                                                                                                                                                                                                                                                                 | proper_nouns                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |   length | translation                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |---:|:------------------------------------------------------------------------------------------------------------------|:---------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------:|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  1 | /home/tajak/Parlamint-translation/ParlaMint-SI/ParlaMint-SI.TEI.ana/ParlaMint-SI_2019-10-23-SDZ8-Redna-12.ana.xml | ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg1.1 | Spoštovane kolegice poslanke , spoštovani kolegi poslanci , gospe in gospodje !                                                                                                                                                                                                                                                                                                                                                                                      | []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |       12 | Dear fellow Members, distinguished fellow Members, ladies and gentlemen!                                                                                                                                                                                                                                                                                                                                                                                |
# |  2 | /home/tajak/Parlamint-translation/ParlaMint-SI/ParlaMint-SI.TEI.ana/ParlaMint-SI_2019-10-23-SDZ8-Redna-12.ana.xml | ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg2.1 | Začenjam nadaljevanje 12. seje  Državnega zbora  .                                                                                                                                                                                                                                                                                                                                                                                                                   | []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |        7 | I begin the continuation of the 12th meeting of the National Assembly.                                                                                                                                                                                                                                                                                                                                                                                  |
# |  3 | /home/tajak/Parlamint-translation/ParlaMint-SI/ParlaMint-SI.TEI.ana/ParlaMint-SI_2019-10-23-SDZ8-Redna-12.ana.xml | ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg3.1 | Obveščen sem , da se današnje seje ne morejo udeležiti naslednje poslanke in poslanci :  Eva Irgl  , mag.  Marko Pogačnik  ,  Jernej Vrtovec  od 17. ure dalje ,  Jožef Horvat  ,  Blaž Pavlin  od 18. do 20. ure , dr.  Franc Trček  ,  Violeta Tomić  do 17. ure ,  Jože Tanko  od 16.30 dalje ,  Janja Sluga  od 15. do 18.30 ,  Mateja Udovč  do 18. ure ,  Primož Siter  od 13.30 do 15.30 ,  Suzana Lep Šimenko  ,  Jelka Godec  in  Igor Zorčič  do 12. ure . | [{15: ['Eva', 'Eva'], 16: ['Irgl', 'Irgl'], 19: ['Marko', 'Marko'], 20: ['Pogačnik', 'Pogačnik'], 22: ['Jernej', 'Jernej'], 23: ['Vrtovec', 'Vrtovec'], 29: ['Jožef', 'Jožef'], 30: ['Horvat', 'Horvat'], 32: ['Blaž', 'Blaž'], 33: ['Pavlin', 'Pavlin'], 41: ['Franc', 'Franc'], 42: ['Trček', 'Trček'], 44: ['Violeta', 'Violeta'], 45: ['Tomić', 'Tomić'], 50: ['Jože', 'Jože'], 51: ['Tanko', 'Tanko'], 56: ['Janja', 'Janja'], 57: ['Sluga', 'Sluga'], 63: ['Mateja', 'Mateja'], 64: ['Udovč', 'Udovč'], 69: ['Primož', 'Primož'], 70: ['Siter', 'Siter'], 76: ['Suzana', 'Suzana'], 77: ['Lep', 'lep'], 78: ['Šimenko', 'Šimenko'], 80: ['Jelka', 'Jelka'], 81: ['Godec', 'Godec'], 83: ['Igor', 'Igor'], 84: ['Zorčič', 'Zorčič']}] |       89 | I am informed that today's meeting cannot be attended by the following Member and Members : Eva Irgl, mag.  Marko Pogačnik, Jernej Vrtovac from 17:00 on, Jožef Horvat, Blaž Pavlin from 18 till 20:00, Dr.  Franc Trček, Violeta Tomić until 17:00, Jože Tanko from 16.30 p.m., Janja Slug from 15.30 p.m. to 18.30 p.m., Mateja Udovč, Primož Siter from 13.30 p.m. to 15.30 p.m., Suzanne Leup Šimenko, Jelka Godec and Igor Zorčič until 12.00 p.m. |
#                                                    file  \
# 1     /home/tajak/Parlamint-translation/ParlaMint-SI...
# 2     /home/tajak/Parlamint-translation/ParlaMint-SI...
# 3     /home/tajak/Parlamint-translation/ParlaMint-SI...
# 4     /home/tajak/Parlamint-translation/ParlaMint-SI...
# 5     /home/tajak/Parlamint-translation/ParlaMint-SI...
# ...                                                 ...
# 2624  /home/tajak/Parlamint-translation/ParlaMint-SI...
# 2625  /home/tajak/Parlamint-translation/ParlaMint-SI...
# 2626  /home/tajak/Parlamint-translation/ParlaMint-SI...
# 2627  /home/tajak/Parlamint-translation/ParlaMint-SI...
# 2628  /home/tajak/Parlamint-translation/ParlaMint-SI...
#
#                                          sentence_id  \
# 1       ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg1.1
# 2       ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg2.1
# 3       ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg3.1
# 4       ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg3.2
# 5       ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg4.1
# ...                                              ...
# 2624  ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg497.1
# 2625  ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg497.2
# 2626  ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg499.1
# 2627  ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg500.1
# 2628  ParlaMint-SI_2019-10-23-SDZ8-Redna-12.seg501.1
#
#                                                    text  \
# 1     Spoštovane kolegice poslanke , spoštovani kole...
# 2     Začenjam nadaljevanje 12. seje  Državnega zbor...
# 3     Obveščen sem , da se današnje seje ne morejo u...
# 4                Vsem prisotnim še enkrat lep pozdrav !
# 5     Prehajamo na 2. , 3. , 4. IN 5. TOČKO DNEVNEGA...
# ...                                                 ...
# 2624                                        Glasujemo .
# 2625  Navzočih je 82 poslank in poslancev , za je gl...
# 2626                 Ugotavljam , da je zakon sprejet .
# 2627  S tem zaključujem to točko dnevnega reda in pr...
# 2628                                   Lep dan naprej .
#
#                                            proper_nouns  length  \
# 1                                                    []      12
# 2                                                    []       7
# 3     [{15: ['Eva', 'Eva'], 16: ['Irgl', 'Irgl'], 19...      89
# 4                                                    []       7
# 5                                                    []      70
# ...                                                 ...     ...
# 2624                                                 []       2
# 2625                                                 []      14
# 2626                                                 []       7
# 2627                                                 []      20
# 2628                                                 []       4
#
#                                             translation
# 1     Dear fellow Members, distinguished fellow Memb...
# 2     I begin the continuation of the 12th meeting o...
# 3     I am informed that today's meeting cannot be a...
# 4                        All present and welcome again!
# 5     We're moving to 2, 3, 4. AND 5. Agenda item — ...
# ...                                                 ...
# 2624                                           We vote.
# 2625  There are 82 Members and Members present, 47 v...
# 2626               I find that the law has been passed.
# 2627  I hereby conclude this agenda item and interru...
# 2628                             Have a nice day ahead.
#
# [2628 rows x 6 columns]

# %%
df = correct_proper_nouns(lang_code)

with pd.option_context('display.max_colwidth', None):
	display(df.iloc[np.where(df["translation_added_spaces"] != df["new_translations"])][["translation", "new_translations"]][:5])
# Out:
# /home/tajak/Parlamint-translation/eflomal
# Number of aligned sentences: 2628
# Issue: index 20: ['Šircelj', 'Šircelj']
# /home/tajak/Parlamint-translation
# |                                                                               |   substituted_words |
# |:------------------------------------------------------------------------------|--------------------:|
# | []                                                                            |                2536 |
# | [('Shircelj', 'Šircelj')]                                                     |                   9 |
# | [('Kordish', 'Kordiš')]                                                       |                   7 |
# | [('Left', 'Levica')]                                                          |                   6 |
# | [('Slovenians', 'Slovenec')]                                                  |                   5 |
# | [('Sarca', 'Šarec')]                                                          |                   4 |
# | [('Divac', 'Divjak')]                                                         |                   3 |
# | [('Šarca', 'Šarec')]                                                          |                   3 |
# | [('Bertonzel', 'Bertoncelj')]                                                 |                   3 |
# | [('č', 'Pavšič')]                                                             |                   2 |
# | [('Levi', 'Levica')]                                                          |                   2 |
# | [('Dijak', 'Divjak')]                                                         |                   2 |
# | [('Luke', 'Luka'), ('Moon', 'Mesec')]                                         |                   1 |
# | [('Luke', 'Luka')]                                                            |                   1 |
# | [('was', 'Stuart'), ('right', 'Mill')]                                        |                   1 |
# | [('colleague', 'Šircelj'), ('Tank', 'Tanko')]                                 |                   1 |
# | [('Micah', 'Miha'), ('Kordish', 'Kordiš'), ('iš', 'Dušan'), ('ško', 'Šiško')] |                   1 |
# | [('Shirclja', 'Šircej'), ('Shircelj', 'Šircelj')]                             |                   1 |
# | [('Marjana', 'Marjan'), ('Sarca', 'Šarec')]                                   |                   1 |
# | [('Sarec', 'Šarec')]                                                          |                   1 |
#                                                                                                                                                                                                                                                                                                                                                                                                                                                  translation  \
# 3    I am informed that today's meeting cannot be attended by the following Member and Members : Eva Irgl, mag.  Marko Pogačnik, Jernej Vrtovac from 17:00 on, Jožef Horvat, Blaž Pavlin from 18 till 20:00, Dr.  Franc Trček, Violeta Tomić until 17:00, Jože Tanko from 16.30 p.m., Janja Slug from 15.30 p.m. to 18.30 p.m., Mateja Udovč, Primož Siter from 13.30 p.m. to 15.30 p.m., Suzanne Leup Šimenko, Jelka Godec and Igor Zorčič until 12.00 p.m.
# 7                                                                                                                                                                                                                                                                                                                                                                                                     That is why I invite Minister Andre Bertoncl to speak.
# 81                                                                                                                                                                                                                                                                                                                                                  The competent working body is the Committee on Finance, and I hereby give the floor to Mr Robert Polnar.
# 113                                                                                                                                                                                                                                               She explained that two editorial comments were being addressed with the amendments of the coalition parliamentary groups, and the amendments of the SDS, the Left and the NSI are of a substantive nature.
# 172                                                                                                                                                                                                                                                                                                                                                     First of all, you have a presentation by Mr Jani Prednik on behalf of the Group of Social Democrats.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    new_translations
# 3    I am informed that today's meeting cannot be attended by the following Member and Members : Eva Irgl , mag . Marko Pogačnik , Jernej Vrtovec from 17 : 00 on , Jožef Horvat , Blaž Pavlin from 18 till 20 : 00 , Dr . Franc Trček , Violeta Tomić until 17 : 00 , Jože Tanko from 16 . 30 p . m . , Janja Sluga from 15 . Mateja Udovč . m . to 18 . 30 p . m . , Mateja Udovč , Primož Siter from 13 . 30 p . m . to 15 . 30 p . m . , Suzana lep Šimenko , Jelka Godec and Igor Zorčič until 12 . 00 p . m .
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                         That is why I invite Minister Andre Bertoncelj to speak .
# 81                                                                                                                                                                                                                                                                                                                                                                                                       The competent working body is the Committee on Finance , and I hereby give the floor to Mr Robert Polnar .
# 113                                                                                                                                                                                                                                                                                                 She explained that two editorial comments were being addressed with the amendments of the coalition parliamentary groups , and the amendments of the SDS , the Levica and the NSI are of a substantive nature .
# 172                                                                                                                                                                                                                                                                                                                                                                                                          First of all , you have a presentation by Mr Jani Prednik on behalf of the Group of Social Democrats .

# %% [markdown]
# ## Functions

# %% [markdown]
# extract_text()

# %%
def extract_text(files_path, lang_code):
	"""
	This function finds paths to all TEI.ana files from the files_path (directory with the files) and saves them to a list.Based on the list, it takes all files,
	extracts text and information on proper nouns from each and saves it into a dataframe.
	It returns the dataframe with extracted text, information on file and sentence_id and proper nouns,
	saved as "ParlaMint-{lang_code}-file-for-MT.csv".

	Args:
	- files_path (string): the directory with the annotated XLM TEI files.
	- lang_code: the lang code that is used in the names of the files, e.g. "SI" in "ParlaMint-SI_2014-08-01-SDZ7-Redna-01.ana"
	"""
	import pandas as pd
	import regex as re
	from bs4 import BeautifulSoup as bs
	import os
	from IPython.display import display
	
	# Get a list of TEI.ana files
	dir_list = os.listdir(files_path)

	# Keep only files with parliamentary sessions (do not include metadata in the list):

	parl_list = []

	for i in dir_list:
		if "ParlaMint-{}_".format(lang_code) in i:
			parl_list.append("{}/{}".format(files_path, i))

	print("Number of files is: {}".format(len(parl_list)))

	# Create an empty df
	df = pd.DataFrame({"file": [""], "sentence_id": [""], "text": [""], "proper_nouns": [""]})

	# Create a regex to separate word id into segment id and word index
	word_seg_re = re.compile("(.*)\.(\d+)")

	for doc in parl_list:
		# Open the file
		file = open("{}".format(doc), "r")
		content = bs(file, 'lxml')

		# Create a list of sentences
		sentence_list = []
		sen_id_list = []
		proper_nouns_list = []

		# Search for all segments
		seg_list = content.find_all("seg")

		for segment in seg_list:
			sentences = segment.find_all("s")
			for sentence in sentences:
				# Get text, replace \n with a space and remove spaces from the beginning and end of string
				sentence_list.append(sentence.getText().replace("\n", " ").strip(" "))
				
				# Add information on sentence id
				sen_id = sentence["xml:id"]
				sen_id_list.append(sen_id)

				# Add information on proper nouns
				current_proper_nouns_list = []

				result = sentence.find_all("name", type = "PER", recursive=False)

				if len(result) > 0:
					word_dict = {}
					for i in result:
						words = i.find_all("w", recursive = False)
						for word in words:
							current_name = word.getText()
							current_lemma = word["lemma"]
							current_word_id = word["xml:id"]
							current_word_index = word_seg_re.findall(current_word_id)[0][1]
							# I'll substract one from the word index, because indexing in the TEI file starts with 1, not 0
							current_word_index = int(current_word_index) - 1
							word_dict[current_word_index] = [current_name, current_lemma]
					
					current_proper_nouns_list.append(word_dict)

				proper_nouns_list.append(current_proper_nouns_list)

		new_df = pd.DataFrame({"sentence_id": sen_id_list, "text": sentence_list, "proper_nouns": proper_nouns_list})
		new_df["file"] = doc

		# Merge df to the previous df
		df = pd.concat([df, new_df])

	# Reset index
	df = df.reset_index(drop=True)

	# Remove the first (empty) row
	df = df.drop([0], axis="index")

	# Add information on length
	df["length"] = df["text"].str.split().str.len()

	print("Number of words in the corpora: {}".format(df["length"].sum()))
	
	# Show the df information
	display(df.describe(include="all"))

	# Save the dataframe
	df.to_csv("results/{}/ParlaMint-{}-file-for-MT.csv".format(lang_code,lang_code), sep="\t")

	return df

# %% [markdown]
# We need to translate the following corpora into English:
# - Belgian (BE) - which language??
# - Bulgarian (BG)
# - Croatian (HR) - We will use "South Slavic MT" based on the manual analysis
# - Czech (CZ)
# - Danish (DK)
# - Dutch (NL)
# - French (FR)
# - Hungarian (HU) - multilingual model only
# - Icelandic (IS)
# - Italian (IT)
# - Latvian (LV)
# - Lithuanian (LT)
# - Polish (PL)
# - Slovenian (SI) - We will use "Slavic MT" based on the results of the manual analysis
# - Spanish? (ES)
# - Turkish (TR)
# - Austrian (AT)
# - Basque (ES-PV)
# - Bosnian (BA)
# - Catalan (ES-CT)
# - Estonian (EE)
# - Finnish (FI)
# - Galician (ES-GA)
# - Greek (GR)
# - Norwegian (NO) - NO OPUS-MT model (!) - we can use GT or eTranslation
# - Portuguese (PT)
# - Romanian (RO)
# - Serbian (RS)
# - Swedish (SE)
# - Ukrainian (UA)

# %% [markdown]
# Explanation of language codes:
# - sla = Slavic
# - zls = South Slavic
# - zlw = West Slavic
# - zle = East Slavic
# - gmq = North Germanic
# - gem = Germanic
# - gmw = West Germanic
# - roa = Romance
# - itc = Italic
# - bat = Baltic
# - trk = Turkic
# - urj = Uralic
# - fiu = Finno-Ugrian

# %%
# Create a dictionary with all possible models for each corpora
lang_models_dict = {"BG": ["bg", "sla", "zls"], "HR": ["zls"], "CZ": ["cs", "sla", "zlw" ], "DK": ["da", "gmq", "gem"], "NL": ["nl", "gem", "gmw"], "FR": ["fr", "itc","roa"], "HU": ["mul"], "IS": ["is","gmq", "gem"], "IT": ["it", "roa", "itc"], "LV": ["lv","bat"], "LT": ["bat"], "PL": ["pl", "sla", "zlw"], "SI": ["sla"], "ES": ["es", "roa", "itc"], "TR": ["tr", "trk" ], "AT": ["de", "gem", "gmw"], "ES-PV": ["eu", "mul"], "BA": ["sla", "zls"], 
"ES-CT": ["ca", "roa", "itc"], "EE": ["et", "urj", "fiu"], "FI": ["fi", "urj", "fiu"], "ES-GA": ["gl", "roa", "itc"], "GR": ["grk"], "PT": ["roa", "itc"], "RO":["roa", "itc"], "RS": ["zls", "sla"], "SE": ["sv", "gmq", "gem"], "UA":["uk", "sla", "zle"]}

# %% [markdown]
# choose_model()

# %%
def choose_model(lang_code):
	"""
	Compare a small sample of translations of all OPUS-MT models that are available
	for the language, to decide which one to use. The function prints out a dataframe with all translations of the sample and saves it as ParlaMint-{lang_code}-sample-model-comparison.csv.

	Args:
	- lang_code: the lang code that is used in the names of the files, it should be the same as for extract_text()
	"""
	import pandas as pd
	import regex as re
	from easynmt import EasyNMT
	from IPython.display import display
	
	lang_models_dict = {"BG": ["bg", "sla", "zls"], "HR": ["zls"], "CZ": ["cs", "sla", "zlw" ], "DK": ["da", "gmq", "gem"], "NL": ["nl", "gem", "gmw"], "FR": ["fr", "itc","roa"], "HU": ["mul"], "IS": ["is","gmq", "gem"], "IT": ["it", "roa", "itc"], "LV": ["lv","bat"], "LT": ["bat"], "PL": ["pl", "sla", "zlw"], "SI": ["sla", "zls"], "ES": ["es", "roa", "itc"], "TR": ["tr", "trk" ], "AT": ["de", "gem", "gmw"], "ES-PV": ["eu", "mul"], "BA": ["sla", "zls"], "ES-CT": ["ca", "roa", "itc"], "EE": ["et", "urj", "fiu"], "FI": ["fi", "urj", "fiu"], "ES-GA": ["gl", "roa", "itc"], "GR": ["grk"], "PT": ["roa", "itc"], "RO":["roa", "itc"], "RS": ["zls", "sla"], "SE": ["sv", "gmq", "gem"], "UA":["uk", "sla", "zle"]}

	# Open the file, created in the previous step
	df = pd.read_csv("results/{}/ParlaMint-{}-file-for-MT.csv".format(lang_code, lang_code), sep="\t", index_col=0)

	# Define the model
	model = EasyNMT('opus-mt')

	print("Entire corpus has {} sentences and {} words.".format(df["text"].count(), df["length"].sum()))

	# Create a smaller sample - just a couple of sentences from one file
	df = df[df.file == list(df["file"].unique())[0]][:20]

	print("Sample files has {} sentences and {} words.".format(df["text"].count(), df["length"].sum()))

	# Create a list of sentences from the df
	sentence_list = df.text.to_list()

	# Translate the sample using all available models for this language
	for opus_lang_code in lang_models_dict[lang_code]:
		translation_list = model.translate(sentence_list, source_lang = "{}".format(opus_lang_code), target_lang='en')

		# Add the translations to the df
		df["translation-{}".format(opus_lang_code)] = translation_list
	
	# Display the df
	with pd.option_context('display.max_colwidth', None):
		display(df.drop(columns=["file", "sentence_id", "proper_nouns", "length"]))

	# Save the df
	df.to_csv("results/{}/ParlaMint-{}-sample-model-comparison.csv".format(lang_code, lang_code), sep="\t")

# %% [markdown]
# translate()

# %%
def translate(lang_code, opus_lang_code):
	"""
	This function translates the text from the dataframe, created with the extract_text() function
	with OPUS-MT models using EasyNMT. It returns a dataframe with the translation.

	Args:
	- lang_code: the lang code that is used in the names of the files, it should be the same as for extract_text()
	- opus_lang_code: the lang code to be used in the OPUS-MT model - use the one that performed the best in the comparison (see function choose_model())
	"""
	import pandas as pd
	import regex as re
	from easynmt import EasyNMT

	# Open the file, created in the previous step
	df = pd.read_csv("results/{}/ParlaMint-{}-file-for-MT.csv".format(lang_code, lang_code), sep="\t", index_col=0)

	# Define the model
	model = EasyNMT('opus-mt')

	print("Entire corpus has {} sentences and {} words.".format(df["text"].count(), df["length"].sum()))

	# Create a list of sentences from the df
	sentence_list = df.text.to_list()

	#Translate the list of sentences - you need to provide the source language as it is in the name of the model - the opus_lang_code
	translation_list = model.translate(sentence_list, source_lang = "{}".format(opus_lang_code), target_lang='en')

	# Add the translations to the df
	df["translation"] = translation_list

	# Display the df
	print(df[:3].to_markdown())

	# Save the df
	df.to_csv("results/{}/ParlaMint-{}-translated.csv".format(lang_code, lang_code), sep="\t")

	return df

# %% [markdown]
# correct_proper_nouns()

# %%
def correct_proper_nouns(lang_code):
	"""
	This function takes the translated text and the source text, aligns words with eflomal and corrects proper nouns.
	It takes the dataframe that was created in the function extract_text() and to which the translation was added
	in the function translate().

	To use eflomal, you need to install it first:
	# !git clone https://github.com/robertostling/eflomal
	# %cd eflomal
	# !make
	# !sudo make install
	# !python3 setup.py install

	Args:
	- lang_code: the lang code that is used in the names of the files, it should be the same as for extract_text()
	"""
	import pandas as pd
	import re
	import ast

	# Open the file, created in the previous step
	df = pd.read_csv("results/{}/ParlaMint-{}-translated.csv".format(lang_code, lang_code), sep="\t", index_col=0)

	# Move into the eflomal folder
	# %cd eflomal

	# In the source text, the punctuation marks are separated from the words.
	# To assure good alignment, we'll do that for the translated text as well.

	translation_list = df.translation.to_list()
	translation_added_spaces = []

	for translation in translation_list:
		# Add spaces around each punctuation
		translation = re.sub('([.,!?:;()])', r' \1 ', translation)
		# Remove duplicated spaces
		translation = re.sub('\s{2,}', ' ', translation)
		translation_added_spaces.append(translation)

	df["translation_added_spaces"] = translation_added_spaces

	# Maybe we'll need to move to the eflomal folder
	#%cd eflomal

	# Then we need to create files for all texts and all translations
	source_sentences = open("source_sentences.txt", "w")
	English_sentences = open("English_sentences.txt", "w")

	for i in df.text.to_list():
		source_sentences.write(i)
		source_sentences.write("\n")

	for i in df.translation_added_spaces.to_list():
		English_sentences.write(i)
		English_sentences.write("\n")

	source_sentences.close()
	English_sentences.close()

	# Align sentences with eflomal and get out a file with alignments
	# !python3 align.py -s source_sentences.txt -t English_sentences.txt --model 3 -r source-en.rev

	# Create a list of alignments from the returned file
	aligns_list = open("source-en.rev", "r").readlines()
	aligns_list = [i.replace("\n", "") for i in aligns_list]
	aligns_list = [i.split(" ") for i in aligns_list]

	final_aligns = []

	# Create a dictionary out of the list
	for i in aligns_list:
		current_line = {}

		try:
			for element in i:
				new_list = element.split("-")

				a = int(new_list[0])
				b = int(new_list[1])
				current_line[a] = b
		
			# Check whether the number of pairs in the list is the same as number of items
			if len(i) != len(list(current_line.items())):
				print("Not okay:")
				print(i)
				print(current_line)

			final_aligns.append(current_line)
		
		except:
			print("error")
			print(aligns_list.index(i))
			print(i)
			final_aligns.append("Error")
		
	print("Number of aligned sentences: {}".format(len(final_aligns)))

	# Add a to the df
	df["alignments"] = final_aligns

	# Remove the rev file
	# %rm source-en.rev

	# When we open the dataframe file, the dictionaries with proper names changed into strings - Change strings in the column proper_nouns into dictionaries

	df["proper_nouns"] = df.proper_nouns.astype("str")
	df["proper_nouns"] = df.proper_nouns.apply(lambda x: ast.literal_eval(x))

	# Remove the list brackets
	df["proper_nouns"] = df.proper_nouns.str[0]

	# Change nan values in the proper_nouns columns
	df = df.fillna(0)

	# Substitute words in the translation based on alignments
	intermediate_list = list(zip(df["translation_added_spaces"], df["proper_nouns"], df["alignments"]))

	new_translations = []
	substituted_all_info = []
	substituted_only = []

	# Add information whether an error occurred
	error_list = []

	for i in intermediate_list:
		current_substituted_list = []
		current_substituted_only = []
		current_error = "No"

		# If no proper names were detected, do not change the translation
		if i[1] == 0:
			new_translations.append(i[0])
		
		else:
			current_translation = i[0]

			# Substitute the word with the Slovene lemma based on the index - loop through the proper nouns to be changed
			for word_index in list(i[1].keys()):
				try:
					# split the translation into list of words
					word_list = current_translation.split()

					# Get index of the substituted word
					substituted_word_index = i[2][word_index]

					# Get the lemma to substitute the word with
					correct_lemma = i[1][word_index][1]

					# If the substitute word and lemma are not the same, get substituted word and its match
					if word_list[substituted_word_index] != correct_lemma:
						current_substituted_list.append((word_list[substituted_word_index], correct_lemma))
						current_substituted_only.append((word_list[substituted_word_index], correct_lemma))

						# Substitute the word in the word list
						word_list[substituted_word_index] = correct_lemma
					
					else:
						# Add information that substitution was not performed
						current_substituted_list.append(f"No substitution: {word_list[substituted_word_index], correct_lemma}")
					
					# Change the translation by merging the words back into a string
					current_translation = " ".join(word_list)

				except:
					print(f"Issue: index {word_index}: {i[1][word_index]}")
					current_error = f"Issue: index {word_index}: {i[1][word_index]}"

			# After the loop through proper nouns, save the new translation
			new_translations.append(current_translation)
		
		# Add information on what was substituted
		substituted_all_info.append(current_substituted_list)
		substituted_only.append(current_substituted_only)
		error_list.append(current_error)


	# Add to the df
	df["new_translations"] = new_translations
	df["substitution_info"] = substituted_all_info
	df["substituted_words"] = substituted_only
	df["errors"] = error_list

	# Change the working directory once again
	# %cd ..

	# Save the df
	df.to_csv("results/{}/ParlaMint-{}-final.csv".format(lang_code, lang_code), sep="\t")

	# Display most common substitutions
	df_substituted = df[df["proper_nouns"] != "0"]
	print(df_substituted.substituted_words.value_counts()[:20].to_markdown())

	return df
